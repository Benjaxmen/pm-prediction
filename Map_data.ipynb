# %%
import pandas as pd
import time
import math
import numpy as np


df=pd.read_csv('processed_data.csv')

# %%
import geetools
import ee
import geemap.core as geemap
ee.Authenticate()
ee.Initialize(project="pm-predictions")

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       mp10    station    mp2.5  dirviento  tamb  so2  velviento     hrel  \
# 0  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 1  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 2  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 3  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 4  146.042  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
#
#        no2       o3      nox       no        co  region       Date  Year  \
# 0  30.3333  16.9167  65.1666  34.8333  0.929165       1 1997-04-02  1997
# 1  30.3333  12.4583  65.1666  34.8333  0.929165       1 1997-04-03  1997
# 2  30.3333  23.2083  65.1666  34.8333  0.929165       1 1997-04-04  1997
# 3  30.3333  28.2917  65.1666  34.8333  0.929165       1 1997-04-05  1997
# 4  30.3333  21.2083  65.1666  34.8333  1.204160       1 1997-04-06  1997
#
#    Month  Day        lat       long
# 0      4    2 -33.547016 -70.666163
# 1      4    3 -33.547016 -70.666163
# 2      4    4 -33.547016 -70.666163
# 3      4    5 -33.547016 -70.666163
# 4      4    6 -33.547016 -70.666163

# %%
df=pd.read_csv('Status.csv')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from datetime import datetime,timedelta
def image_task(image,point,folder_name, image_name,storage="Drive"):

    """
    function to download satellite images from a ee.imageCollection object.
    We first generate a bounding box of image_res*n_pixels meters around "point",
    then we clip that region from the image collection, take the mean image from the collection,
    and send that as a task to the Google Earth Engine.
    After that, we download the image Google Cloud Storage if storage=="Cloud",
    or to Google Drive if storage=="Drive".

    Inputs:
    -image= ee.ImageCollection object
    -point= ee.Geometry.Point object
    -image_res= resolution of the image in meters
    -n_pixels= number of pixels to extract on the images
    -storage= string indicating if we are storing the images in Google Cloud or Google Drive.
              Defaults to Google Cloud.
    -folder_name= string with Google Cloud bucket name if storage=="Cloud"
                  string with the name of a folder in the root of Google Drive if storage=="Drive"
    -image_name= string with the image_name for the TIFF image.

    Output:
     task= an EE task object. we can then use task.status() to check the status of the task.
     If the task is completed, we will see a TIFF image in "folder_name" with name "image_name.tif".
     The image has 3 dimensions, where the first 2 are n_pixels, and the 3rd is the number of bands of "image".
    """
    #generating the box around the point
    len=30*224 # for landsat, 30 meters * 224 pixels
    region= point.buffer(len/2).bounds().getInfo()['coordinates']
    #defining the rectangle
    coords=np.array(region)
    #taking min and maxs of coordinates to define the rectangle
    coords=[np.min(coords[:,:,0]), np.min(coords[:,:,1]), np.max(coords[:,:,0]), np.max(coords[:,:,1])]
    rectangle=ee.Geometry.Rectangle(coords)

    #generating the export task ( dimensions is "WIDTHxHEIGHT"  )
    if storage=="Cloud":
        task=ee.batch.Export.image.toCloudStorage(image=image.filterBounds(rectangle).mean(),
                            bucket=folder_name,
                            description=image_name,
                            region=str(region), dimensions=str(224)+"x"+str(224))
    if storage=="Drive":
        task=ee.batch.Export.image.toDrive(image=image.filterBounds(rectangle).mean(),
                            folder=folder_name,
                            description=image_name,
                            region=str(region), dimensions=str(224)+"x"+str(224))


    #starting the task
    task.start()
    return task

def imagery(date):
    ''' function to decide what imagery we are using depending on the year, and
    to take composites from the relevant year for our ground truth '''
    year=date.year 
    end_date = date + timedelta(days=5)
    if date>datetime.strptime('2013-03-18', '%Y-%m-%d'): #in this case we use landsat 8
        #getting collection
        landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1")

        #filtering dates
        landsat=landsat.filterDate(str(year)+'-'+str(date.month)+'-'+str(date.day), str(end_date.year)+'-'+str(end_date.month)+'-'+str(end_date.day))

        #applying cloud masking


        # selecting bands for both versions

        landsat = landsat.select(["B2","B3","B4","B5","B6","B7"])

    elif date>datetime.strptime('1999-05-28', '%Y-%m-%d'):
        landsat = ee.ImageCollection("LANDSAT/LE07/C02/T1")
        #filtering dates
        landsat=landsat.filterDate(str(year)+'-'+str(date.month)+'-'+str(date.day), str(end_date.year)+'-'+str(end_date.month)+'-'+str(end_date.day))

        #applying cloud masking


        # selecting bands for both versions

        landsat = landsat.select(["B1","B2","B3","B4","B5","B7"])
    else:
        landsat = ee.ImageCollection("LANDSAT/LT05/C02/T1")
        #filtering dates
        landsat=landsat.filterDate(str(year)+'-'+str(date.month)+'-'+str(date.day), str(end_date.year)+'-'+str(end_date.month)+'-'+str(end_date.day))



        # selecting bands for both versions

        landsat = landsat.select(["B1","B2","B3","B4","B5","B7"])


    # filtering date (taking a full year)

    return landsat


#list to store the task objects
tasks=[]

#running the tasks to get the imagery
batch_size=1000
starting_index=120000
N=len(df)
for j in range( math.ceil(N/batch_size) ):
    #determining batch lower and upper indexes, given batch size
    #lower is always fixed
    lower_i=starting_index+batch_size*j
    #upper can vary at the end of the list
    if batch_size*(j+1)>N:
        upper_i=starting_index+N
    else:
        upper_i=starting_index+batch_size*(j+1)


    #generating the tasks for all the images in the batch
    for i in range(lower_i,upper_i):
        tasks.append(image_task(image=imagery(df['Date'][i]),
                                point=ee.Geometry.Point(df['long'][i],df['lat'][i] ),
                                folder_name='GEE_Images',
                                image_name=str(df['station'][i]+'_'+str(df['Date'][i])),
                                storage="Drive"))

    #printing message:
    print('Batch '+str(j+1)+': Retrieving images '+str(lower_i+1)+' to '+str(upper_i)+' of a total of '+str(starting_index+N))

    #checking status of the mentioned tasks
    batch_status=df.loc[lower_i:upper_i-1,'task_status'].value_counts() #counting status of the tasks

    while batch_status.get('COMPLETED',0) + batch_status.get('FAILED',0)< upper_i - lower_i: #checking that not all tasks are done
        time.sleep(10) #running the code every 10 seconds
        for i in range(lower_i,upper_i):
            #checking status of each task
            if df.loc[i,'task_status']=='_' or df.loc[i,'task_status']=='READY' or df.loc[i,'task_status']=='RUNNING':
                df.loc[i,'task_status']=tasks[i-starting_index].status()['state'] #use when restarting list of tasks
                #dataset.loc[i,'task_status']=tasks[i].status()['state']

        #updating batch status
        batch_status=df.loc[lower_i:upper_i-1,'task_status'].value_counts()
        #reporting them back
        print('Status of batch '+str(j+1)+':')
        print('completed images= '+str(batch_status.get('COMPLETED',0)))
        print('failed images= '+str(batch_status.get('FAILED',0)))
        print('pending images= '+str(upper_i-lower_i -batch_status.get('COMPLETED',0)-batch_status.get('FAILED',0)))
        print('------------------')

    #updating dataset after every batch

    df.to_csv('Status.csv',index=False)

print('The Landsat download code has finished')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Batch 1: Retrieving images 111001 to 112000 of a total of 262917
# Status of batch 1:
# completed images= 48
# failed images= 134
# pending images= 818
# ------------------
# Status of batch 1:
# completed images= 61
# failed images= 166
# pending images= 773
# ------------------
# Status of batch 1:
# completed images= 78
# failed images= 210
# pending images= 712
# ------------------
# Status of batch 1:
# completed images= 90
# failed images= 231
# pending images= 679
# ------------------
# Status of batch 1:
# completed images= 100
# failed images= 254
# pending images= 646
# ------------------
# Status of batch 1:
# completed images= 111
# failed images= 276
# pending images= 613
# ------------------
# Status of batch 1:
# completed images= 119
# failed images= 298
# pending images= 583
# ------------------
# Status of batch 1:
# completed images= 133
# failed images= 322
# pending images= 545
# ------------------
# Status of batch 1:
# completed images= 136
# failed images= 347
# pending images= 517
# ------------------
# Status of batch 1:
# completed images= 145
# failed images= 369
# pending images= 486
# ------------------
# Status of batch 1:
# completed images= 157
# failed images= 395
# pending images= 448
# ------------------
# Status of batch 1:
# completed images= 167
# failed images= 413
# pending images= 420
# ------------------
# Status of batch 1:
# completed images= 177
# failed images= 430
# pending images= 393
# ------------------
# Status of batch 1:
# completed images= 182
# failed images= 452
# pending images= 366
# ------------------
# Status of batch 1:
# completed images= 190
# failed images= 464
# pending images= 346
# ------------------
# Status of batch 1:
# completed images= 192
# failed images= 484
# pending images= 324
# ------------------
# Status of batch 1:
# completed images= 192
# failed images= 486
# pending images= 322
# ------------------
# Status of batch 1:
# completed images= 197
# failed images= 501
# pending images= 302
# ------------------
# Status of batch 1:
# completed images= 205
# failed images= 512
# pending images= 283
# ------------------
# Status of batch 1:
# completed images= 212
# failed images= 527
# pending images= 261
# ------------------
# Status of batch 1:
# completed images= 217
# failed images= 545
# pending images= 238
# ------------------
# Status of batch 1:
# completed images= 222
# failed images= 556
# pending images= 222
# ------------------
# Status of batch 1:
# completed images= 226
# failed images= 565
# pending images= 209
# ------------------
# Status of batch 1:
# completed images= 229
# failed images= 567
# pending images= 204
# ------------------
# Status of batch 1:
# completed images= 235
# failed images= 578
# pending images= 187
# ------------------
# Status of batch 1:
# completed images= 237
# failed images= 589
# pending images= 174
# ------------------
# Status of batch 1:
# completed images= 242
# failed images= 592
# pending images= 166
# ------------------
# Status of batch 1:
# completed images= 246
# failed images= 602
# pending images= 152
# ------------------
# Status of batch 1:
# completed images= 247
# failed images= 610
# pending images= 143
# ------------------
# Status of batch 1:
# completed images= 252
# failed images= 615
# pending images= 133
# ------------------
# Status of batch 1:
# completed images= 254
# failed images= 622
# pending images= 124
# ------------------
# Status of batch 1:
# completed images= 257
# failed images= 632
# pending images= 111
# ------------------
# Status of batch 1:
# completed images= 261
# failed images= 633
# pending images= 106
# ------------------
# Status of batch 1:
# completed images= 261
# failed images= 644
# pending images= 95
# ------------------
# Status of batch 1:
# completed images= 266
# failed images= 645
# pending images= 89
# ------------------
# Status of batch 1:
# completed images= 267
# failed images= 654
# pending images= 79
# ------------------
# Status of batch 1:
# completed images= 271
# failed images= 655
# pending images= 74
# ------------------
# Status of batch 1:
# completed images= 272
# failed images= 666
# pending images= 62
# ------------------
# Status of batch 1:
# completed images= 277
# failed images= 676
# pending images= 47
# ------------------
# Status of batch 1:
# completed images= 280
# failed images= 677
# pending images= 43
# ------------------
# Status of batch 1:
# completed images= 282
# failed images= 682
# pending images= 36
# ------------------
# Status of batch 1:
# completed images= 282
# failed images= 688
# pending images= 30
# ------------------
# Status of batch 1:
# completed images= 284
# failed images= 688
# pending images= 28
# ------------------
# Status of batch 1:
# completed images= 286
# failed images= 691
# pending images= 23
# ------------------
# Status of batch 1:
# completed images= 287
# failed images= 697
# pending images= 16
# ------------------
# Status of batch 1:
# completed images= 288
# failed images= 699
# pending images= 13
# ------------------
# Status of batch 1:
# completed images= 291
# failed images= 701
# pending images= 8
# ------------------
# Status of batch 1:
# completed images= 292
# failed images= 708
# pending images= 0
# ------------------
# Batch 2: Retrieving images 112001 to 113000 of a total of 262917
# Status of batch 2:
# completed images= 55
# failed images= 161
# pending images= 784
# ------------------
# Status of batch 2:
# completed images= 73
# failed images= 205
# pending images= 722
# ------------------
# Status of batch 2:
# completed images= 85
# failed images= 237
# pending images= 678
# ------------------
# Status of batch 2:
# completed images= 100
# failed images= 270
# pending images= 630
# ------------------
# Status of batch 2:
# completed images= 115
# failed images= 299
# pending images= 586
# ------------------
# Status of batch 2:
# completed images= 126
# failed images= 324
# pending images= 550
# ------------------
# Status of batch 2:
# completed images= 135
# failed images= 362
# pending images= 503
# ------------------
# Status of batch 2:
# completed images= 145
# failed images= 392
# pending images= 463
# ------------------
# Status of batch 2:
# completed images= 153
# failed images= 412
# pending images= 435
# ------------------
# Status of batch 2:
# completed images= 160
# failed images= 429
# pending images= 411
# ------------------
# Status of batch 2:
# completed images= 167
# failed images= 445
# pending images= 388
# ------------------
# Status of batch 2:
# completed images= 175
# failed images= 461
# pending images= 364
# ------------------
# Status of batch 2:
# completed images= 180
# failed images= 478
# pending images= 342
# ------------------
# Status of batch 2:
# completed images= 190
# failed images= 495
# pending images= 315
# ------------------
# Status of batch 2:
# completed images= 195
# failed images= 511
# pending images= 294
# ------------------
# Status of batch 2:
# completed images= 202
# failed images= 522
# pending images= 276
# ------------------
# Status of batch 2:
# completed images= 206
# failed images= 533
# pending images= 261
# ------------------
# Status of batch 2:
# completed images= 210
# failed images= 544
# pending images= 246
# ------------------
# Status of batch 2:
# completed images= 215
# failed images= 556
# pending images= 229
# ------------------
# Status of batch 2:
# completed images= 219
# failed images= 572
# pending images= 209
# ------------------
# Status of batch 2:
# completed images= 221
# failed images= 582
# pending images= 197
# ------------------
# Status of batch 2:
# completed images= 225
# failed images= 587
# pending images= 188
# ------------------
# Status of batch 2:
# completed images= 228
# failed images= 594
# pending images= 178
# ------------------
# Status of batch 2:
# completed images= 233
# failed images= 604
# pending images= 163
# ------------------
# Status of batch 2:
# completed images= 235
# failed images= 615
# pending images= 150
# ------------------
# Status of batch 2:
# completed images= 240
# failed images= 626
# pending images= 134
# ------------------
# Status of batch 2:
# completed images= 245
# failed images= 635
# pending images= 120
# ------------------
# Status of batch 2:
# completed images= 250
# failed images= 643
# pending images= 107
# ------------------
# Status of batch 2:
# completed images= 253
# failed images= 649
# pending images= 98
# ------------------
# Status of batch 2:
# completed images= 255
# failed images= 659
# pending images= 86
# ------------------
# Status of batch 2:
# completed images= 260
# failed images= 662
# pending images= 78
# ------------------
# Status of batch 2:
# completed images= 260
# failed images= 670
# pending images= 70
# ------------------
# Status of batch 2:
# completed images= 264
# failed images= 673
# pending images= 63
# ------------------
# Status of batch 2:
# completed images= 265
# failed images= 681
# pending images= 54
# ------------------
# Status of batch 2:
# completed images= 269
# failed images= 683
# pending images= 48
# ------------------
# Status of batch 2:
# completed images= 270
# failed images= 692
# pending images= 38
# ------------------
# Status of batch 2:
# completed images= 272
# failed images= 692
# pending images= 36
# ------------------
# Status of batch 2:
# completed images= 275
# failed images= 694
# pending images= 31
# ------------------
# Status of batch 2:
# completed images= 275
# failed images= 703
# pending images= 22
# ------------------
# Status of batch 2:
# completed images= 275
# failed images= 703
# pending images= 22
# ------------------
# Status of batch 2:
# completed images= 279
# failed images= 703
# pending images= 18
# ------------------
# Status of batch 2:
# completed images= 280
# failed images= 708
# pending images= 12
# ------------------
# Status of batch 2:
# completed images= 280
# failed images= 714
# pending images= 6
# ------------------
# Status of batch 2:
# completed images= 282
# failed images= 714
# pending images= 4
# ------------------
# Status of batch 2:
# completed images= 283
# failed images= 715
# pending images= 2
# ------------------
# Status of batch 2:
# completed images= 284
# failed images= 715
# pending images= 1
# ------------------
# Status of batch 2:
# completed images= 285
# failed images= 715
# pending images= 0
# ------------------
# Batch 3: Retrieving images 113001 to 114000 of a total of 262917
# Status of batch 3:
# completed images= 50
# failed images= 120
# pending images= 830
# ------------------
# Status of batch 3:
# completed images= 70
# failed images= 164
# pending images= 766
# ------------------
# Status of batch 3:
# completed images= 85
# failed images= 197
# pending images= 718
# ------------------
# Status of batch 3:
# completed images= 100
# failed images= 230
# pending images= 670
# ------------------
# Status of batch 3:
# completed images= 112
# failed images= 268
# pending images= 620
# ------------------
# Status of batch 3:
# completed images= 120
# failed images= 306
# pending images= 574
# ------------------
# Status of batch 3:
# completed images= 134
# failed images= 329
# pending images= 537
# ------------------
# Status of batch 3:
# completed images= 141
# failed images= 365
# pending images= 494
# ------------------
# Status of batch 3:
# completed images= 149
# failed images= 384
# pending images= 467
# ------------------
# Status of batch 3:
# completed images= 157
# failed images= 399
# pending images= 444
# ------------------
# Status of batch 3:
# completed images= 165
# failed images= 421
# pending images= 414
# ------------------
# Status of batch 3:
# completed images= 175
# failed images= 443
# pending images= 382
# ------------------
# Status of batch 3:
# completed images= 184
# failed images= 465
# pending images= 351
# ------------------
# Status of batch 3:
# completed images= 190
# failed images= 486
# pending images= 324
# ------------------
# Status of batch 3:
# completed images= 195
# failed images= 512
# pending images= 293
# ------------------
# Status of batch 3:
# completed images= 200
# failed images= 530
# pending images= 270
# ------------------
# Status of batch 3:
# completed images= 206
# failed images= 539
# pending images= 255
# ------------------
# Status of batch 3:
# completed images= 214
# failed images= 555
# pending images= 231
# ------------------
# Status of batch 3:
# completed images= 215
# failed images= 579
# pending images= 206
# ------------------
# Status of batch 3:
# completed images= 220
# failed images= 588
# pending images= 192
# ------------------
# Status of batch 3:
# completed images= 225
# failed images= 601
# pending images= 174
# ------------------
# Status of batch 3:
# completed images= 231
# failed images= 612
# pending images= 157
# ------------------
# Status of batch 3:
# completed images= 237
# failed images= 623
# pending images= 140
# ------------------
# Status of batch 3:
# completed images= 240
# failed images= 634
# pending images= 126
# ------------------
# Status of batch 3:
# completed images= 245
# failed images= 643
# pending images= 112
# ------------------
# Status of batch 3:
# completed images= 248
# failed images= 646
# pending images= 106
# ------------------
# Status of batch 3:
# completed images= 250
# failed images= 650
# pending images= 100
# ------------------
# Status of batch 3:
# completed images= 253
# failed images= 657
# pending images= 90
# ------------------
# Status of batch 3:
# completed images= 255
# failed images= 667
# pending images= 78
# ------------------
# Status of batch 3:
# completed images= 260
# failed images= 671
# pending images= 69
# ------------------
# Status of batch 3:
# completed images= 260
# failed images= 675
# pending images= 65
# ------------------
# Status of batch 3:
# completed images= 260
# failed images= 678
# pending images= 62
# ------------------
# Status of batch 3:
# completed images= 265
# failed images= 683
# pending images= 52
# ------------------
# Status of batch 3:
# completed images= 265
# failed images= 689
# pending images= 46
# ------------------
# Status of batch 3:
# completed images= 270
# failed images= 690
# pending images= 40
# ------------------
# Status of batch 3:
# completed images= 270
# failed images= 700
# pending images= 30
# ------------------
# Status of batch 3:
# completed images= 274
# failed images= 702
# pending images= 24
# ------------------
# Status of batch 3:
# completed images= 275
# failed images= 709
# pending images= 16
# ------------------
# Status of batch 3:
# completed images= 275
# failed images= 711
# pending images= 14
# ------------------
# Status of batch 3:
# completed images= 276
# failed images= 711
# pending images= 13
# ------------------
# Status of batch 3:
# completed images= 279
# failed images= 713
# pending images= 8
# ------------------
# Status of batch 3:
# completed images= 279
# failed images= 715
# pending images= 6
# ------------------
# Status of batch 3:
# completed images= 280
# failed images= 719
# pending images= 1
# ------------------
# Status of batch 3:
# completed images= 280
# failed images= 720
# pending images= 0
# ------------------
# Batch 4: Retrieving images 114001 to 115000 of a total of 262917
# Status of batch 4:
# completed images= 57
# failed images= 123
# pending images= 820
# ------------------
# Status of batch 4:
# completed images= 75
# failed images= 167
# pending images= 758
# ------------------
# Status of batch 4:
# completed images= 95
# failed images= 211
# pending images= 694
# ------------------
# Status of batch 4:
# completed images= 113
# failed images= 244
# pending images= 643
# ------------------
# Status of batch 4:
# completed images= 126
# failed images= 277
# pending images= 597
# ------------------
# Status of batch 4:
# completed images= 140
# failed images= 310
# pending images= 550
# ------------------
# Status of batch 4:
# completed images= 155
# failed images= 343
# pending images= 502
# ------------------
# Status of batch 4:
# completed images= 166
# failed images= 365
# pending images= 469
# ------------------
# Status of batch 4:
# completed images= 175
# failed images= 403
# pending images= 422
# ------------------
# Status of batch 4:
# completed images= 188
# failed images= 426
# pending images= 386
# ------------------
# Status of batch 4:
# completed images= 194
# failed images= 453
# pending images= 353
# ------------------
# Status of batch 4:
# completed images= 203
# failed images= 475
# pending images= 322
# ------------------
# Status of batch 4:
# completed images= 210
# failed images= 494
# pending images= 296
# ------------------
# Status of batch 4:
# completed images= 215
# failed images= 508
# pending images= 277
# ------------------
# Status of batch 4:
# completed images= 224
# failed images= 521
# pending images= 255
# ------------------
# Status of batch 4:
# completed images= 230
# failed images= 541
# pending images= 229
# ------------------
# Status of batch 4:
# completed images= 240
# failed images= 558
# pending images= 202
# ------------------
# Status of batch 4:
# completed images= 244
# failed images= 572
# pending images= 184
# ------------------
# Status of batch 4:
# completed images= 251
# failed images= 585
# pending images= 164
# ------------------
# Status of batch 4:
# completed images= 254
# failed images= 595
# pending images= 151
# ------------------
# Status of batch 4:
# completed images= 260
# failed images= 605
# pending images= 135
# ------------------
# Status of batch 4:
# completed images= 265
# failed images= 616
# pending images= 119
# ------------------
# Status of batch 4:
# completed images= 269
# failed images= 626
# pending images= 105
# ------------------
# Status of batch 4:
# completed images= 272
# failed images= 629
# pending images= 99
# ------------------
# Status of batch 4:
# completed images= 274
# failed images= 638
# pending images= 88
# ------------------
# Status of batch 4:
# completed images= 276
# failed images= 640
# pending images= 84
# ------------------
# Status of batch 4:
# completed images= 279
# failed images= 640
# pending images= 81
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 650
# pending images= 70
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 666
# pending images= 54
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 678
# pending images= 42
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 683
# pending images= 37
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 691
# pending images= 29
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 699
# pending images= 21
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 714
# pending images= 6
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 717
# pending images= 3
# ------------------
# Status of batch 4:
# completed images= 280
# failed images= 720
# pending images= 0
# ------------------
# Batch 5: Retrieving images 115001 to 116000 of a total of 262917
# Status of batch 5:
# completed images= 40
# failed images= 189
# pending images= 771
# ------------------
# Status of batch 5:
# completed images= 50
# failed images= 243
# pending images= 707
# ------------------
# Status of batch 5:
# completed images= 56
# failed images= 297
# pending images= 647
# ------------------
# Status of batch 5:
# completed images= 70
# failed images= 322
# pending images= 608
# ------------------
# Status of batch 5:
# completed images= 80
# failed images= 360
# pending images= 560
# ------------------
# Status of batch 5:
# completed images= 82
# failed images= 415
# pending images= 503
# ------------------
# Status of batch 5:
# completed images= 90
# failed images= 454
# pending images= 456
# ------------------
# Status of batch 5:
# completed images= 99
# failed images= 478
# pending images= 423
# ------------------
# Status of batch 5:
# completed images= 107
# failed images= 503
# pending images= 390
# ------------------
# Status of batch 5:
# completed images= 107
# failed images= 552
# pending images= 341
# ------------------
# Status of batch 5:
# completed images= 107
# failed images= 584
# pending images= 309
# ------------------
# Status of batch 5:
# completed images= 111
# failed images= 594
# pending images= 295
# ------------------
# Status of batch 5:
# completed images= 112
# failed images= 630
# pending images= 258
# ------------------
# Status of batch 5:
# completed images= 114
# failed images= 650
# pending images= 236
# ------------------
# Status of batch 5:
# completed images= 117
# failed images= 665
# pending images= 218
# ------------------
# Status of batch 5:
# completed images= 117
# failed images= 677
# pending images= 206
# ------------------
# Status of batch 5:
# completed images= 122
# failed images= 695
# pending images= 183
# ------------------
# Status of batch 5:
# completed images= 126
# failed images= 700
# pending images= 174
# ------------------
# Status of batch 5:
# completed images= 127
# failed images= 720
# pending images= 153
# ------------------
# Status of batch 5:
# completed images= 132
# failed images= 727
# pending images= 141
# ------------------
# Status of batch 5:
# completed images= 135
# failed images= 732
# pending images= 133
# ------------------
# Status of batch 5:
# completed images= 137
# failed images= 743
# pending images= 120
# ------------------
# Status of batch 5:
# completed images= 142
# failed images= 752
# pending images= 106
# ------------------
# Status of batch 5:
# completed images= 146
# failed images= 755
# pending images= 99
# ------------------
# Status of batch 5:
# completed images= 147
# failed images= 765
# pending images= 88
# ------------------
# Status of batch 5:
# completed images= 152
# failed images= 768
# pending images= 80
# ------------------
# Status of batch 5:
# completed images= 155
# failed images= 778
# pending images= 67
# ------------------
# Status of batch 5:
# completed images= 157
# failed images= 784
# pending images= 59
# ------------------
# Status of batch 5:
# completed images= 159
# failed images= 788
# pending images= 53
# ------------------
# Status of batch 5:
# completed images= 162
# failed images= 796
# pending images= 42
# ------------------
# Status of batch 5:
# completed images= 164
# failed images= 799
# pending images= 37
# ------------------
# Status of batch 5:
# completed images= 167
# failed images= 803
# pending images= 30
# ------------------
# Status of batch 5:
# completed images= 167
# failed images= 807
# pending images= 26
# ------------------
# Status of batch 5:
# completed images= 167
# failed images= 810
# pending images= 23
# ------------------
# Status of batch 5:
# completed images= 169
# failed images= 810
# pending images= 21
# ------------------
# Status of batch 5:
# completed images= 172
# failed images= 817
# pending images= 11
# ------------------
# Status of batch 5:
# completed images= 172
# failed images= 821
# pending images= 7
# ------------------
# Status of batch 5:
# completed images= 174
# failed images= 821
# pending images= 5
# ------------------
# Status of batch 5:
# completed images= 177
# failed images= 821
# pending images= 2
# ------------------
# Status of batch 5:
# completed images= 177
# failed images= 823
# pending images= 0
# ------------------
# Batch 6: Retrieving images 116001 to 117000 of a total of 262917
# Status of batch 6:
# completed images= 35
# failed images= 169
# pending images= 796
# ------------------
# Status of batch 6:
# completed images= 47
# failed images= 198
# pending images= 755
# ------------------
# Status of batch 6:
# completed images= 59
# failed images= 240
# pending images= 701
# ------------------
# Status of batch 6:
# completed images= 74
# failed images= 271
# pending images= 655
# ------------------
# Status of batch 6:
# completed images= 85
# failed images= 298
# pending images= 617
# ------------------
# Status of batch 6:
# completed images= 95
# failed images= 326
# pending images= 579
# ------------------
# Status of batch 6:
# completed images= 105
# failed images= 354
# pending images= 541
# ------------------
# Status of batch 6:
# completed images= 115
# failed images= 387
# pending images= 498
# ------------------
# Status of batch 6:
# completed images= 124
# failed images= 403
# pending images= 473
# ------------------
# Status of batch 6:
# completed images= 129
# failed images= 422
# pending images= 449
# ------------------
# Status of batch 6:
# completed images= 137
# failed images= 436
# pending images= 427
# ------------------
# Status of batch 6:
# completed images= 143
# failed images= 455
# pending images= 402
# ------------------
# Status of batch 6:
# completed images= 153
# failed images= 474
# pending images= 373
# ------------------
# Status of batch 6:
# completed images= 163
# failed images= 492
# pending images= 345
# ------------------
# Status of batch 6:
# completed images= 169
# failed images= 513
# pending images= 318
# ------------------
# Status of batch 6:
# completed images= 177
# failed images= 531
# pending images= 292
# ------------------
# Status of batch 6:
# completed images= 182
# failed images= 547
# pending images= 271
# ------------------
# Status of batch 6:
# completed images= 184
# failed images= 562
# pending images= 254
# ------------------
# Status of batch 6:
# completed images= 192
# failed images= 579
# pending images= 229
# ------------------
# Status of batch 6:
# completed images= 192
# failed images= 610
# pending images= 198
# ------------------
# Status of batch 6:
# completed images= 192
# failed images= 627
# pending images= 181
# ------------------
# Status of batch 6:
# completed images= 192
# failed images= 645
# pending images= 163
# ------------------
# Status of batch 6:
# completed images= 197
# failed images= 651
# pending images= 152
# ------------------
# Status of batch 6:
# completed images= 197
# failed images= 665
# pending images= 138
# ------------------
# Status of batch 6:
# completed images= 197
# failed images= 682
# pending images= 121
# ------------------
# Status of batch 6:
# completed images= 200
# failed images= 691
# pending images= 109
# ------------------
# Status of batch 6:
# completed images= 202
# failed images= 700
# pending images= 98
# ------------------
# Status of batch 6:
# completed images= 207
# failed images= 705
# pending images= 88
# ------------------
# Status of batch 6:
# completed images= 207
# failed images= 727
# pending images= 66
# ------------------
# Status of batch 6:
# completed images= 209
# failed images= 727
# pending images= 64
# ------------------
# Status of batch 6:
# completed images= 212
# failed images= 733
# pending images= 55
# ------------------
# Status of batch 6:
# completed images= 212
# failed images= 737
# pending images= 51
# ------------------
# Status of batch 6:
# completed images= 216
# failed images= 738
# pending images= 46
# ------------------
# Status of batch 6:
# completed images= 217
# failed images= 744
# pending images= 39
# ------------------
# Status of batch 6:
# completed images= 217
# failed images= 749
# pending images= 34
# ------------------
# Status of batch 6:
# completed images= 220
# failed images= 750
# pending images= 30
# ------------------
# Status of batch 6:
# completed images= 222
# failed images= 758
# pending images= 20
# ------------------
# Status of batch 6:
# completed images= 223
# failed images= 760
# pending images= 17
# ------------------
# Status of batch 6:
# completed images= 225
# failed images= 760
# pending images= 15
# ------------------
# Status of batch 6:
# completed images= 226
# failed images= 761
# pending images= 13
# ------------------
# Status of batch 6:
# completed images= 226
# failed images= 766
# pending images= 8
# ------------------
# Status of batch 6:
# completed images= 227
# failed images= 769
# pending images= 4
# ------------------
# Status of batch 6:
# completed images= 228
# failed images= 771
# pending images= 1
# ------------------
# Status of batch 6:
# completed images= 229
# failed images= 771
# pending images= 0
# ------------------
# Batch 7: Retrieving images 117001 to 118000 of a total of 262917
# Status of batch 7:
# completed images= 58
# failed images= 125
# pending images= 817
# ------------------
# Status of batch 7:
# completed images= 72
# failed images= 170
# pending images= 758
# ------------------
# Status of batch 7:
# completed images= 88
# failed images= 214
# pending images= 698
# ------------------
# Status of batch 7:
# completed images= 101
# failed images= 252
# pending images= 647
# ------------------
# Status of batch 7:
# completed images= 118
# failed images= 285
# pending images= 597
# ------------------
# Status of batch 7:
# completed images= 128
# failed images= 316
# pending images= 556
# ------------------
# Status of batch 7:
# completed images= 138
# failed images= 327
# pending images= 535
# ------------------
# Status of batch 7:
# completed images= 146
# failed images= 350
# pending images= 504
# ------------------
# Status of batch 7:
# completed images= 148
# failed images= 392
# pending images= 460
# ------------------
# Status of batch 7:
# completed images= 163
# failed images= 430
# pending images= 407
# ------------------
# Status of batch 7:
# completed images= 171
# failed images= 452
# pending images= 377
# ------------------
# Status of batch 7:
# completed images= 179
# failed images= 474
# pending images= 347
# ------------------
# Status of batch 7:
# completed images= 188
# failed images= 489
# pending images= 323
# ------------------
# Status of batch 7:
# completed images= 193
# failed images= 506
# pending images= 301
# ------------------
# Status of batch 7:
# completed images= 201
# failed images= 518
# pending images= 281
# ------------------
# Status of batch 7:
# completed images= 207
# failed images= 530
# pending images= 263
# ------------------
# Status of batch 7:
# completed images= 213
# failed images= 551
# pending images= 236
# ------------------
# Status of batch 7:
# completed images= 218
# failed images= 562
# pending images= 220
# ------------------
# Status of batch 7:
# completed images= 223
# failed images= 572
# pending images= 205
# ------------------
# Status of batch 7:
# completed images= 228
# failed images= 583
# pending images= 189
# ------------------
# Status of batch 7:
# completed images= 233
# failed images= 595
# pending images= 172
# ------------------
# Status of batch 7:
# completed images= 238
# failed images= 597
# pending images= 165
# ------------------
# Status of batch 7:
# completed images= 238
# failed images= 617
# pending images= 145
# ------------------
# Status of batch 7:
# completed images= 238
# failed images= 633
# pending images= 129
# ------------------
# Status of batch 7:
# completed images= 238
# failed images= 648
# pending images= 114
# ------------------
# Status of batch 7:
# completed images= 238
# failed images= 668
# pending images= 94
# ------------------
# Status of batch 7:
# completed images= 238
# failed images= 685
# pending images= 77
# ------------------
# Status of batch 7:
# completed images= 241
# failed images= 686
# pending images= 73
# ------------------
# Status of batch 7:
# completed images= 243
# failed images= 694
# pending images= 63
# ------------------
# Status of batch 7:
# completed images= 245
# failed images= 696
# pending images= 59
# ------------------
# Status of batch 7:
# completed images= 248
# failed images= 702
# pending images= 50
# ------------------
# Status of batch 7:
# completed images= 248
# failed images= 716
# pending images= 36
# ------------------
# Status of batch 7:
# completed images= 248
# failed images= 724
# pending images= 28
# ------------------
# Status of batch 7:
# completed images= 251
# failed images= 725
# pending images= 24
# ------------------
# Status of batch 7:
# completed images= 253
# failed images= 728
# pending images= 19
# ------------------
# Status of batch 7:
# completed images= 253
# failed images= 734
# pending images= 13
# ------------------
# Status of batch 7:
# completed images= 255
# failed images= 735
# pending images= 10
# ------------------
# Status of batch 7:
# completed images= 257
# failed images= 736
# pending images= 7
# ------------------
# Status of batch 7:
# completed images= 258
# failed images= 742
# pending images= 0
# ------------------
# Batch 8: Retrieving images 118001 to 119000 of a total of 262917
# Status of batch 8:
# completed images= 45
# failed images= 102
# pending images= 853
# ------------------
# Status of batch 8:
# completed images= 63
# failed images= 153
# pending images= 784
# ------------------
# Status of batch 8:
# completed images= 75
# failed images= 185
# pending images= 740
# ------------------
# Status of batch 8:
# completed images= 87
# failed images= 207
# pending images= 706
# ------------------
# Status of batch 8:
# completed images= 98
# failed images= 229
# pending images= 673
# ------------------
# Status of batch 8:
# completed images= 107
# failed images= 267
# pending images= 626
# ------------------
# Status of batch 8:
# completed images= 119
# failed images= 289
# pending images= 592
# ------------------
# Status of batch 8:
# completed images= 126
# failed images= 311
# pending images= 563
# ------------------
# Status of batch 8:
# completed images= 136
# failed images= 333
# pending images= 531
# ------------------
# Status of batch 8:
# completed images= 145
# failed images= 355
# pending images= 500
# ------------------
# Status of batch 8:
# completed images= 157
# failed images= 377
# pending images= 466
# ------------------
# Status of batch 8:
# completed images= 167
# failed images= 399
# pending images= 434
# ------------------
# Status of batch 8:
# completed images= 175
# failed images= 421
# pending images= 404
# ------------------
# Status of batch 8:
# completed images= 185
# failed images= 436
# pending images= 379
# ------------------
# Status of batch 8:
# completed images= 195
# failed images= 458
# pending images= 347
# ------------------
# Status of batch 8:
# completed images= 203
# failed images= 476
# pending images= 321
# ------------------
# Status of batch 8:
# completed images= 210
# failed images= 498
# pending images= 292
# ------------------
# Status of batch 8:
# completed images= 218
# failed images= 509
# pending images= 273
# ------------------
# Status of batch 8:
# completed images= 223
# failed images= 522
# pending images= 255
# ------------------
# Status of batch 8:
# completed images= 230
# failed images= 537
# pending images= 233
# ------------------
# Status of batch 8:
# completed images= 234
# failed images= 549
# pending images= 217
# ------------------
# Status of batch 8:
# completed images= 240
# failed images= 563
# pending images= 197
# ------------------
# Status of batch 8:
# completed images= 245
# failed images= 574
# pending images= 181
# ------------------
# Status of batch 8:
# completed images= 250
# failed images= 583
# pending images= 167
# ------------------
# Status of batch 8:
# completed images= 255
# failed images= 589
# pending images= 156
# ------------------
# Status of batch 8:
# completed images= 258
# failed images= 597
# pending images= 145
# ------------------
# Status of batch 8:
# completed images= 261
# failed images= 608
# pending images= 131
# ------------------
# Status of batch 8:
# completed images= 265
# failed images= 619
# pending images= 116
# ------------------
# Status of batch 8:
# completed images= 269
# failed images= 621
# pending images= 110
# ------------------
# Status of batch 8:
# completed images= 271
# failed images= 630
# pending images= 99
# ------------------
# Status of batch 8:
# completed images= 275
# failed images= 639
# pending images= 86
# ------------------
# Status of batch 8:
# completed images= 278
# failed images= 642
# pending images= 80
# ------------------
# Status of batch 8:
# completed images= 280
# failed images= 645
# pending images= 75
# ------------------
# Status of batch 8:
# completed images= 280
# failed images= 660
# pending images= 60
# ------------------
# Status of batch 8:
# completed images= 281
# failed images= 668
# pending images= 51
# ------------------
# Status of batch 8:
# completed images= 284
# failed images= 669
# pending images= 47
# ------------------
# Status of batch 8:
# completed images= 284
# failed images= 673
# pending images= 43
# ------------------
# Status of batch 8:
# completed images= 285
# failed images= 679
# pending images= 36
# ------------------
# Status of batch 8:
# completed images= 289
# failed images= 681
# pending images= 30
# ------------------
# Status of batch 8:
# completed images= 290
# failed images= 689
# pending images= 21
# ------------------
# Status of batch 8:
# completed images= 290
# failed images= 697
# pending images= 13
# ------------------
# Status of batch 8:
# completed images= 290
# failed images= 704
# pending images= 6
# ------------------
# Status of batch 8:
# completed images= 290
# failed images= 706
# pending images= 4
# ------------------
# Status of batch 8:
# completed images= 293
# failed images= 706
# pending images= 1
# ------------------
# Status of batch 8:
# completed images= 294
# failed images= 706
# pending images= 0
# ------------------
# Batch 9: Retrieving images 119001 to 120000 of a total of 262917
# Status of batch 9:
# completed images= 53
# failed images= 152
# pending images= 795
# ------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 138
#     135 for i in range(lower_i,upper_i):
#     136     #checking status of each task
#     137     if df.loc[i,'task_status']=='_' or df.loc[i,'task_status']=='READY' or df.loc[i,'task_status']=='RUNNING':
# --> 138         df.loc[i,'task_status']=tasks[i-starting_index].status()['state'] #use when restarting list of tasks
#     139         #dataset.loc[i,'task_status']=tasks[i].status()['state']
#     140
#     141 #updating batch status
#     142 batch_status=df.loc[lower_i:upper_i-1,'task_status'].value_counts()
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/batch.py:176, in Task.status(self)
#     163 """Fetches the current status of the task.
#     164
#     165 Returns:
#    (...)
#     173   May also include other fields.
#     174 """
#     175 if self.operation_name:
# --> 176   operation = data.getOperation(self.operation_name)
#     177   result = _cloud_api_utils.convert_operation_to_task(operation)
#     178   if result['state'] == 'UNKNOWN':
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/data.py:1701, in getOperation(operation_name)
#    1691 def getOperation(operation_name: str) -> Any:
#    1692   """Retrieves the status of a long-running operation.
#    1693
#    1694   Args:
#    (...)
#    1699     An Operation status dictionary for the requested operation.
#    1700   """
# -> 1701   return _execute_cloud_call(
#    1702       _get_cloud_projects().operations().get(name=operation_name)
#    1703   )
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/data.py:402, in _execute_cloud_call(call, num_retries)
#     388 """Executes a Cloud API call and translates errors to EEExceptions.
#     389
#     390 Args:
#    (...)
#     399   EEException if the call fails.
#     400 """
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#     404   raise _translate_cloud_exception(e)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/_cloud_api_utils.py:70, in _Http.request(***failed resolving arguments***)
#      63 del redirections  # Ignored
#      65 try:
#      66   # googleapiclient is expecting an httplib2 object, and doesn't include
#      67   # requests error in the list of transient errors. Therefore, transient
#      68   # requests errors should be converted to kinds that googleapiclient
#      69   # consider transient.
# ---> 70   response = self._session.request(
#      71       method, uri, data=body, headers=headers, timeout=self._timeout
#      72   )
#      73 except requests.exceptions.ConnectionError as connection_error:
#      74   raise ConnectionError(connection_error) from connection_error
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/ee/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/miniconda3/envs/ee/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniconda3/envs/ee/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/ee/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/miniconda3/envs/ee/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/ee/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Dropout, Bidirectional, Input, concatenate,Reshape
from keras.utils import plot_model

# Definición del modelo CNN
input1 = Input(shape=(None, 100, 100, 8)) # Asume que tus imágenes son de 100x100 con 8 canales
cnn = TimeDistributed(Conv2D(64, kernel_size=3, activation='relu'))(input1)
cnn = TimeDistributed(MaxPooling2D(2))(cnn)
cnn = TimeDistributed(Conv2D(128, kernel_size=3, activation='relu'))(cnn)
cnn = TimeDistributed(MaxPooling2D(2))(cnn)
cnn = TimeDistributed(Conv2D(64, kernel_size=3, activation='relu'))(cnn)
cnn = TimeDistributed(MaxPooling2D(2))(cnn)
cnn = TimeDistributed(Flatten())(cnn)

# Definición del modelo LSTM
input2 = Input(shape=(None, 14)) # Asume que tienes 14 características tabuladas
dense = TimeDistributed(Dense(128, activation='relu'))(input2)
dense = TimeDistributed(Dropout(0.5))(dense)
dense = TimeDistributed(Dense(64, activation='relu'))(dense)
dense = TimeDistributed(Dropout(0.5))(dense)
dense = TimeDistributed(Dense(32, activation='relu'))(dense)

# Combinación de los modelos
merge = concatenate([cnn, dense])
lstm = Bidirectional(LSTM(100, return_sequences=True))(merge)
lstm = Dropout(0.5)(lstm)
lstm = Bidirectional(LSTM(100, return_sequences=False))(lstm)
lstm = Dropout(0.5)(lstm)

# Capa de salida
output = Dense(1, activation='linear')(lstm) # Asume que estás haciendo una regresión

# Creación del modelo
model = Model([input1, input2], output)
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
