# %%
import pandas as pd
import time
import math
import numpy as np


df=pd.read_csv('processed_data.csv')

# %%
import geetools
import ee
import geemap.core as geemap
ee.Authenticate()
ee.Initialize(project="pm-predictions")

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       mp10    station    mp2.5  dirviento  tamb  so2  velviento     hrel  \
# 0  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 1  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 2  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 3  178.542  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
# 4  146.042  El_bosque  49.7829    221.195   NaN  9.5   0.950428  40.5833
#
#        no2       o3      nox       no        co  region       Date  Year  \
# 0  30.3333  16.9167  65.1666  34.8333  0.929165       1 1997-04-02  1997
# 1  30.3333  12.4583  65.1666  34.8333  0.929165       1 1997-04-03  1997
# 2  30.3333  23.2083  65.1666  34.8333  0.929165       1 1997-04-04  1997
# 3  30.3333  28.2917  65.1666  34.8333  0.929165       1 1997-04-05  1997
# 4  30.3333  21.2083  65.1666  34.8333  1.204160       1 1997-04-06  1997
#
#    Month  Day        lat       long
# 0      4    2 -33.547016 -70.666163
# 1      4    3 -33.547016 -70.666163
# 2      4    4 -33.547016 -70.666163
# 3      4    5 -33.547016 -70.666163
# 4      4    6 -33.547016 -70.666163

# %%
import datetime
def image_task(image,point,folder_name, image_name,storage="Drive"):

    """
    function to download satellite images from a ee.imageCollection object.
    We first generate a bounding box of image_res*n_pixels meters around "point",
    then we clip that region from the image collection, take the mean image from the collection,
    and send that as a task to the Google Earth Engine.
    After that, we download the image Google Cloud Storage if storage=="Cloud",
    or to Google Drive if storage=="Drive".

    Inputs:
    -image= ee.ImageCollection object
    -point= ee.Geometry.Point object
    -image_res= resolution of the image in meters
    -n_pixels= number of pixels to extract on the images
    -storage= string indicating if we are storing the images in Google Cloud or Google Drive.
              Defaults to Google Cloud.
    -folder_name= string with Google Cloud bucket name if storage=="Cloud"
                  string with the name of a folder in the root of Google Drive if storage=="Drive"
    -image_name= string with the image_name for the TIFF image.

    Output:
     task= an EE task object. we can then use task.status() to check the status of the task.
     If the task is completed, we will see a TIFF image in "folder_name" with name "image_name.tif".
     The image has 3 dimensions, where the first 2 are n_pixels, and the 3rd is the number of bands of "image".
    """
    #generating the box around the point
    len=30*224 # for landsat, 30 meters * 224 pixels
    region= point.buffer(len/2).bounds().getInfo()['coordinates']
    #defining the rectangle
    coords=np.array(region)
    #taking min and maxs of coordinates to define the rectangle
    coords=[np.min(coords[:,:,0]), np.min(coords[:,:,1]), np.max(coords[:,:,0]), np.max(coords[:,:,1])]
    rectangle=ee.Geometry.Rectangle(coords)

    #generating the export task ( dimensions is "WIDTHxHEIGHT"  )
    if storage=="Cloud":
        task=ee.batch.Export.image.toCloudStorage(image=image.filterBounds(rectangle).mean(),
                            bucket=folder_name,
                            description=image_name,
                            region=str(region), dimensions=str(224)+"x"+str(224))
    if storage=="Drive":
        task=ee.batch.Export.image.toDrive(image=image.filterBounds(rectangle).mean(),
                            folder=folder_name,
                            description=image_name,
                            region=str(region), dimensions=str(224)+"x"+str(224))


    #starting the task
    task.start()
    return task

def imagery(date):
    ''' function to decide what imagery we are using depending on the year, and
    to take composites from the relevant year for our ground truth '''
    year=date.year
    end_date = date + datetime.timedelta(days=10)
    if year>2013: #in this case we use landsat 8
        #getting collection
        landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")

        #filtering dates
        landsat=landsat.filterDate(str(year)+'-'+str(date.month)+'-'+str(date.day), str(end_date.year)+'-'+str(end_date.month)+'-'+str(end_date.day))

        #applying cloud masking


        # selecting bands for both versions

        landsat = landsat.select(["B2","B3","B4","B5","B6","B7"])

    elif year>1999:
        landsat = ee.ImageCollection("LANDSAT/LE07/C02/T1")
        #filtering dates
        landsat=landsat.filterDate(str(year)+'-'+str(date.month)+'-'+str(date.day), str(end_date.year)+'-'+str(end_date.month)+'-'+str(end_date.day))

        #applying cloud masking


        # selecting bands for both versions

        landsat = landsat.select(["B1","B2","B3","B4","B5","B7"])
    else:
        landsat = ee.ImageCollection("LANDSAT/LT05/C02/T1")
        #filtering dates
        landsat=landsat.filterDate(str(year)+'-'+str(date.month)+'-'+str(date.day), str(end_date.year)+'-'+str(end_date.month)+'-'+str(end_date.day))



        # selecting bands for both versions

        landsat = landsat.select(["B1","B2","B3","B4","B5","B7"])


    # filtering date (taking a full year)

    return landsat


df['original_index'] = df.index

# column for task status
df['task_status']='_'

#list to store the task objects
tasks=[]

#running the tasks to get the imagery
batch_size=500
starting_index=21700
N=len(df)
for j in range( math.ceil(N/batch_size) ):
    #determining batch lower and upper indexes, given batch size
    #lower is always fixed
    lower_i=starting_index+batch_size*j
    #upper can vary at the end of the list
    if batch_size*(j+1)>N:
        upper_i=starting_index+N
    else:
        upper_i=starting_index+batch_size*(j+1)


    #generating the tasks for all the images in the batch
    for i in range(lower_i,upper_i):
        tasks.append(image_task(image=imagery(df['Date'][i]),
                                point=ee.Geometry.Point(df['long'][i],df['lat'][i] ),
                                folder_name='GEE_Images',
                                image_name=str(df['station'][i]+'_'+str(df['Date'][i])),
                                storage="Drive"))

    #printing message:
    print('Batch '+str(j+1)+': Retrieving images '+str(lower_i+1)+' to '+str(upper_i)+' of a total of '+str(starting_index+N))

    #checking status of the mentioned tasks
    batch_status=df.loc[lower_i:upper_i-1,'task_status'].value_counts() #counting status of the tasks

    while batch_status.get('COMPLETED',0) + batch_status.get('FAILED',0)< upper_i - lower_i: #checking that not all tasks are done
        time.sleep(10) #running the code every 10 seconds
        for i in range(lower_i,upper_i):
            #checking status of each task
            if df.loc[i,'task_status']=='_' or df.loc[i,'task_status']=='READY' or df.loc[i,'task_status']=='RUNNING':
                df.loc[i,'task_status']=tasks[i-starting_index].status()['state'] #use when restarting list of tasks
                #dataset.loc[i,'task_status']=tasks[i].status()['state']

        #updating batch status
        batch_status=df.loc[lower_i:upper_i-1,'task_status'].value_counts()
        #reporting them back
        print('Status of batch '+str(j+1)+':')
        print('completed images= '+str(batch_status.get('COMPLETED',0)))
        print('failed images= '+str(batch_status.get('FAILED',0)))
        print('pending images= '+str(upper_i-lower_i -batch_status.get('COMPLETED',0)-batch_status.get('FAILED',0)))
        print('------------------')

    #updating dataset after every batch

    df.to_csv('Status.csv',index=False)

print('The Landsat download code has finished')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Batch 1: Retrieving images 14201 to 14700 of a total of 166117
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 0
# failed images= 0
# pending images= 500
# ------------------
# Status of batch 1:
# completed images= 2
# failed images= 0
# pending images= 498
# ------------------
# Status of batch 1:
# completed images= 12
# failed images= 8
# pending images= 480
# ------------------
# Status of batch 1:
# completed images= 21
# failed images= 13
# pending images= 466
# ------------------
# Status of batch 1:
# completed images= 32
# failed images= 18
# pending images= 450
# ------------------
# Status of batch 1:
# completed images= 38
# failed images= 24
# pending images= 438
# ------------------
# Status of batch 1:
# completed images= 46
# failed images= 30
# pending images= 424
# ------------------
# Status of batch 1:
# completed images= 52
# failed images= 35
# pending images= 413
# ------------------
# Status of batch 1:
# completed images= 55
# failed images= 52
# pending images= 393
# ------------------
# Status of batch 1:
# completed images= 62
# failed images= 58
# pending images= 380
# ------------------
# Status of batch 1:
# completed images= 72
# failed images= 62
# pending images= 366
# ------------------
# Status of batch 1:
# completed images= 74
# failed images= 80
# pending images= 346
# ------------------
# Status of batch 1:
# completed images= 82
# failed images= 83
# pending images= 335
# ------------------
# Status of batch 1:
# completed images= 88
# failed images= 86
# pending images= 326
# ------------------
# Status of batch 1:
# completed images= 95
# failed images= 92
# pending images= 313
# ------------------
# Status of batch 1:
# completed images= 102
# failed images= 97
# pending images= 301
# ------------------
# Status of batch 1:
# completed images= 108
# failed images= 98
# pending images= 294
# ------------------
# Status of batch 1:
# completed images= 112
# failed images= 104
# pending images= 284
# ------------------
# Status of batch 1:
# completed images= 118
# failed images= 104
# pending images= 278
# ------------------
# Status of batch 1:
# completed images= 122
# failed images= 110
# pending images= 268
# ------------------
# Status of batch 1:
# completed images= 130
# failed images= 110
# pending images= 260
# ------------------
# Status of batch 1:
# completed images= 134
# failed images= 116
# pending images= 250
# ------------------
# Status of batch 1:
# completed images= 142
# failed images= 118
# pending images= 240
# ------------------
# Status of batch 1:
# completed images= 147
# failed images= 122
# pending images= 231
# ------------------
# Status of batch 1:
# completed images= 152
# failed images= 123
# pending images= 225
# ------------------
# Status of batch 1:
# completed images= 155
# failed images= 128
# pending images= 217
# ------------------
# Status of batch 1:
# completed images= 161
# failed images= 129
# pending images= 210
# ------------------
# Status of batch 1:
# completed images= 166
# failed images= 134
# pending images= 200
# ------------------
# Status of batch 1:
# completed images= 173
# failed images= 140
# pending images= 187
# ------------------
# Status of batch 1:
# completed images= 178
# failed images= 140
# pending images= 182
# ------------------
# Status of batch 1:
# completed images= 181
# failed images= 140
# pending images= 179
# ------------------
# Status of batch 1:
# completed images= 184
# failed images= 146
# pending images= 170
# ------------------
# Status of batch 1:
# completed images= 188
# failed images= 146
# pending images= 166
# ------------------
# Status of batch 1:
# completed images= 192
# failed images= 150
# pending images= 158
# ------------------
# Status of batch 1:
# completed images= 196
# failed images= 152
# pending images= 152
# ------------------
# Status of batch 1:
# completed images= 200
# failed images= 152
# pending images= 148
# ------------------
# Status of batch 1:
# completed images= 202
# failed images= 158
# pending images= 140
# ------------------
# Status of batch 1:
# completed images= 206
# failed images= 158
# pending images= 136
# ------------------
# Status of batch 1:
# completed images= 212
# failed images= 159
# pending images= 129
# ------------------
# Status of batch 1:
# completed images= 214
# failed images= 164
# pending images= 122
# ------------------
# Status of batch 1:
# completed images= 218
# failed images= 164
# pending images= 118
# ------------------
# Status of batch 1:
# completed images= 221
# failed images= 165
# pending images= 114
# ------------------
# Status of batch 1:
# completed images= 222
# failed images= 170
# pending images= 108
# ------------------
# Status of batch 1:
# completed images= 224
# failed images= 170
# pending images= 106
# ------------------
# Status of batch 1:
# completed images= 229
# failed images= 170
# pending images= 101
# ------------------
# Status of batch 1:
# completed images= 232
# failed images= 172
# pending images= 96
# ------------------
# Status of batch 1:
# completed images= 232
# failed images= 176
# pending images= 92
# ------------------
# Status of batch 1:
# completed images= 236
# failed images= 176
# pending images= 88
# ------------------
# Status of batch 1:
# completed images= 239
# failed images= 176
# pending images= 85
# ------------------
# Status of batch 1:
# completed images= 242
# failed images= 181
# pending images= 77
# ------------------
# Status of batch 1:
# completed images= 243
# failed images= 182
# pending images= 75
# ------------------
# Status of batch 1:
# completed images= 246
# failed images= 182
# pending images= 72
# ------------------
# Status of batch 1:
# completed images= 248
# failed images= 182
# pending images= 70
# ------------------
# Status of batch 1:
# completed images= 251
# failed images= 182
# pending images= 67
# ------------------
# Status of batch 1:
# completed images= 252
# failed images= 188
# pending images= 60
# ------------------
# Status of batch 1:
# completed images= 254
# failed images= 188
# pending images= 58
# ------------------
# Status of batch 1:
# completed images= 256
# failed images= 188
# pending images= 56
# ------------------
# Status of batch 1:
# completed images= 260
# failed images= 188
# pending images= 52
# ------------------
# Status of batch 1:
# completed images= 262
# failed images= 190
# pending images= 48
# ------------------
# Status of batch 1:
# completed images= 262
# failed images= 195
# pending images= 43
# ------------------
# Status of batch 1:
# completed images= 262
# failed images= 201
# pending images= 37
# ------------------
# Status of batch 1:
# completed images= 262
# failed images= 207
# pending images= 31
# ------------------
# Status of batch 1:
# completed images= 262
# failed images= 209
# pending images= 29
# ------------------
# Status of batch 1:
# completed images= 263
# failed images= 209
# pending images= 28
# ------------------
# Status of batch 1:
# completed images= 264
# failed images= 210
# pending images= 26
# ------------------
# Status of batch 1:
# completed images= 266
# failed images= 210
# pending images= 24
# ------------------
# Status of batch 1:
# completed images= 267
# failed images= 210
# pending images= 23
# ------------------
# Status of batch 1:
# completed images= 270
# failed images= 210
# pending images= 20
# ------------------
# Status of batch 1:
# completed images= 271
# failed images= 210
# pending images= 19
# ------------------
# Status of batch 1:
# completed images= 272
# failed images= 212
# pending images= 16
# ------------------
# Status of batch 1:
# completed images= 272
# failed images= 216
# pending images= 12
# ------------------
# Status of batch 1:
# completed images= 273
# failed images= 216
# pending images= 11
# ------------------
# Status of batch 1:
# completed images= 274
# failed images= 216
# pending images= 10
# ------------------
# Status of batch 1:
# completed images= 276
# failed images= 216
# pending images= 8
# ------------------
# Status of batch 1:
# completed images= 278
# failed images= 216
# pending images= 6
# ------------------
# Status of batch 1:
# completed images= 279
# failed images= 216
# pending images= 5
# ------------------
# Status of batch 1:
# completed images= 280
# failed images= 216
# pending images= 4
# ------------------
# Status of batch 1:
# completed images= 281
# failed images= 216
# pending images= 3
# ------------------
# Status of batch 1:
# completed images= 282
# failed images= 218
# pending images= 0
# ------------------
# Batch 2: Retrieving images 14701 to 15200 of a total of 166117
# Status of batch 2:
# completed images= 27
# failed images= 16
# pending images= 457
# ------------------
# Status of batch 2:
# completed images= 37
# failed images= 22
# pending images= 441
# ------------------
# Status of batch 2:
# completed images= 47
# failed images= 28
# pending images= 425
# ------------------
# Status of batch 2:
# completed images= 50
# failed images= 47
# pending images= 403
# ------------------
# Status of batch 2:
# completed images= 59
# failed images= 51
# pending images= 390
# ------------------
# Status of batch 2:
# completed images= 67
# failed images= 56
# pending images= 377
# ------------------
# Status of batch 2:
# completed images= 75
# failed images= 62
# pending images= 363
# ------------------
# Status of batch 2:
# completed images= 82
# failed images= 68
# pending images= 350
# ------------------
# Status of batch 2:
# completed images= 90
# failed images= 71
# pending images= 339
# ------------------
# Status of batch 2:
# completed images= 98
# failed images= 74
# pending images= 328
# ------------------
# Status of batch 2:
# completed images= 102
# failed images= 79
# pending images= 319
# ------------------
# Status of batch 2:
# completed images= 110
# failed images= 81
# pending images= 309
# ------------------
# Status of batch 2:
# completed images= 116
# failed images= 86
# pending images= 298
# ------------------
# Status of batch 2:
# completed images= 122
# failed images= 92
# pending images= 286
# ------------------
# Status of batch 2:
# completed images= 126
# failed images= 92
# pending images= 282
# ------------------
# Status of batch 2:
# completed images= 129
# failed images= 95
# pending images= 276
# ------------------
# Status of batch 2:
# completed images= 130
# failed images= 98
# pending images= 272
# ------------------
# Status of batch 2:
# completed images= 133
# failed images= 98
# pending images= 269
# ------------------
# Status of batch 2:
# completed images= 140
# failed images= 100
# pending images= 260
# ------------------
# Status of batch 2:
# completed images= 143
# failed images= 104
# pending images= 253
# ------------------
# Status of batch 2:
# completed images= 148
# failed images= 104
# pending images= 248
# ------------------
# Status of batch 2:
# completed images= 152
# failed images= 110
# pending images= 238
# ------------------
# Status of batch 2:
# completed images= 159
# failed images= 111
# pending images= 230
# ------------------
# Status of batch 2:
# completed images= 160
# failed images= 124
# pending images= 216
# ------------------
# Status of batch 2:
# completed images= 162
# failed images= 132
# pending images= 206
# ------------------
# Status of batch 2:
# completed images= 170
# failed images= 134
# pending images= 196
# ------------------
# Status of batch 2:
# completed images= 175
# failed images= 138
# pending images= 187
# ------------------
# Status of batch 2:
# completed images= 181
# failed images= 144
# pending images= 175
# ------------------
# Status of batch 2:
# completed images= 190
# failed images= 147
# pending images= 163
# ------------------
# Status of batch 2:
# completed images= 194
# failed images= 150
# pending images= 156
# ------------------
# Status of batch 2:
# completed images= 199
# failed images= 151
# pending images= 150
# ------------------
# Status of batch 2:
# completed images= 203
# failed images= 156
# pending images= 141
# ------------------
# Status of batch 2:
# completed images= 210
# failed images= 159
# pending images= 131
# ------------------
# Status of batch 2:
# completed images= 214
# failed images= 162
# pending images= 124
# ------------------
# Status of batch 2:
# completed images= 218
# failed images= 162
# pending images= 120
# ------------------
# Status of batch 2:
# completed images= 220
# failed images= 168
# pending images= 112
# ------------------
# Status of batch 2:
# completed images= 226
# failed images= 168
# pending images= 106
# ------------------
# Status of batch 2:
# completed images= 229
# failed images= 170
# pending images= 101
# ------------------
# Status of batch 2:
# completed images= 230
# failed images= 174
# pending images= 96
# ------------------
# Status of batch 2:
# completed images= 235
# failed images= 174
# pending images= 91
# ------------------
# Status of batch 2:
# completed images= 240
# failed images= 179
# pending images= 81
# ------------------
# Status of batch 2:
# completed images= 243
# failed images= 180
# pending images= 77
# ------------------
# Status of batch 2:
# completed images= 247
# failed images= 180
# pending images= 73
# ------------------
# Status of batch 2:
# completed images= 250
# failed images= 186
# pending images= 64
# ------------------
# Status of batch 2:
# completed images= 253
# failed images= 186
# pending images= 61
# ------------------
# Status of batch 2:
# completed images= 258
# failed images= 186
# pending images= 56
# ------------------
# Status of batch 2:
# completed images= 259
# failed images= 191
# pending images= 50
# ------------------
# Status of batch 2:
# completed images= 261
# failed images= 192
# pending images= 47
# ------------------
# Status of batch 2:
# completed images= 265
# failed images= 192
# pending images= 43
# ------------------
# Status of batch 2:
# completed images= 268
# failed images= 193
# pending images= 39
# ------------------
# Status of batch 2:
# completed images= 270
# failed images= 198
# pending images= 32
# ------------------
# Status of batch 2:
# completed images= 272
# failed images= 198
# pending images= 30
# ------------------
# Status of batch 2:
# completed images= 275
# failed images= 198
# pending images= 27
# ------------------
# Status of batch 2:
# completed images= 278
# failed images= 198
# pending images= 24
# ------------------
# Status of batch 2:
# completed images= 280
# failed images= 203
# pending images= 17
# ------------------
# Status of batch 2:
# completed images= 280
# failed images= 212
# pending images= 8
# ------------------
# Status of batch 2:
# completed images= 280
# failed images= 218
# pending images= 2
# ------------------
# Status of batch 2:
# completed images= 280
# failed images= 220
# pending images= 0
# ------------------
# Batch 3: Retrieving images 15201 to 15700 of a total of 166117
# Status of batch 3:
# completed images= 19
# failed images= 78
# pending images= 403
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 123
# pending images= 358
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 158
# pending images= 323
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 192
# pending images= 289
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 215
# pending images= 266
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 228
# pending images= 253
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 245
# pending images= 236
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 268
# pending images= 213
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 295
# pending images= 186
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 309
# pending images= 172
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 326
# pending images= 155
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 347
# pending images= 134
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 362
# pending images= 119
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 378
# pending images= 103
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 390
# pending images= 91
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 398
# pending images= 83
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 404
# pending images= 77
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 415
# pending images= 66
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 424
# pending images= 57
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 433
# pending images= 48
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 439
# pending images= 42
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 446
# pending images= 35
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 449
# pending images= 32
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 455
# pending images= 26
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 460
# pending images= 21
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 469
# pending images= 12
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 477
# pending images= 4
# ------------------
# Status of batch 3:
# completed images= 19
# failed images= 481
# pending images= 0
# ------------------
# Batch 4: Retrieving images 15701 to 16200 of a total of 166117
# Status of batch 4:
# completed images= 0
# failed images= 99
# pending images= 401
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 139
# pending images= 361
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 171
# pending images= 329
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 197
# pending images= 303
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 230
# pending images= 270
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 262
# pending images= 238
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 290
# pending images= 210
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 316
# pending images= 184
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 335
# pending images= 165
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 355
# pending images= 145
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 375
# pending images= 125
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 387
# pending images= 113
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 395
# pending images= 105
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 409
# pending images= 91
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 422
# pending images= 78
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 429
# pending images= 71
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 441
# pending images= 59
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 453
# pending images= 47
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 462
# pending images= 38
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 474
# pending images= 26
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 483
# pending images= 17
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 491
# pending images= 9
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 493
# pending images= 7
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 496
# pending images= 4
# ------------------
# Status of batch 4:
# completed images= 0
# failed images= 500
# pending images= 0
# ------------------
# Batch 5: Retrieving images 16201 to 16700 of a total of 166117
# Status of batch 5:
# completed images= 0
# failed images= 103
# pending images= 397
# ------------------
# Status of batch 5:
# completed images= 5
# failed images= 130
# pending images= 365
# ------------------
# Status of batch 5:
# completed images= 20
# failed images= 143
# pending images= 337
# ------------------
# Status of batch 5:
# completed images= 22
# failed images= 172
# pending images= 306
# ------------------
# Status of batch 5:
# completed images= 36
# failed images= 178
# pending images= 286
# ------------------
# Status of batch 5:
# completed images= 42
# failed images= 200
# pending images= 258
# ------------------
# Status of batch 5:
# completed images= 49
# failed images= 216
# pending images= 235
# ------------------
# Status of batch 5:
# completed images= 54
# failed images= 234
# pending images= 212
# ------------------
# Status of batch 5:
# completed images= 59
# failed images= 255
# pending images= 186
# ------------------
# Status of batch 5:
# completed images= 69
# failed images= 258
# pending images= 173
# ------------------
# Status of batch 5:
# completed images= 75
# failed images= 261
# pending images= 164
# ------------------
# Status of batch 5:
# completed images= 82
# failed images= 267
# pending images= 151
# ------------------
# Status of batch 5:
# completed images= 89
# failed images= 273
# pending images= 138
# ------------------
# Status of batch 5:
# completed images= 98
# failed images= 273
# pending images= 129
# ------------------
# Status of batch 5:
# completed images= 101
# failed images= 279
# pending images= 120
# ------------------
# Status of batch 5:
# completed images= 107
# failed images= 280
# pending images= 113
# ------------------
# Status of batch 5:
# completed images= 113
# failed images= 285
# pending images= 102
# ------------------
# Status of batch 5:
# completed images= 117
# failed images= 291
# pending images= 92
# ------------------
# Status of batch 5:
# completed images= 117
# failed images= 307
# pending images= 76
# ------------------
# Status of batch 5:
# completed images= 121
# failed images= 307
# pending images= 72
# ------------------
# Status of batch 5:
# completed images= 125
# failed images= 307
# pending images= 68
# ------------------
# Status of batch 5:
# completed images= 129
# failed images= 313
# pending images= 58
# ------------------
# Status of batch 5:
# completed images= 132
# failed images= 313
# pending images= 55
# ------------------
# Status of batch 5:
# completed images= 137
# failed images= 317
# pending images= 46
# ------------------
# Status of batch 5:
# completed images= 140
# failed images= 319
# pending images= 41
# ------------------
# Status of batch 5:
# completed images= 142
# failed images= 319
# pending images= 39
# ------------------
# Status of batch 5:
# completed images= 145
# failed images= 319
# pending images= 36
# ------------------
# Status of batch 5:
# completed images= 146
# failed images= 321
# pending images= 33
# ------------------
# Status of batch 5:
# completed images= 146
# failed images= 325
# pending images= 29
# ------------------
# Status of batch 5:
# completed images= 151
# failed images= 325
# pending images= 24
# ------------------
# Status of batch 5:
# completed images= 154
# failed images= 325
# pending images= 21
# ------------------
# Status of batch 5:
# completed images= 156
# failed images= 330
# pending images= 14
# ------------------
# Status of batch 5:
# completed images= 158
# failed images= 331
# pending images= 11
# ------------------
# Status of batch 5:
# completed images= 160
# failed images= 331
# pending images= 9
# ------------------
# Status of batch 5:
# completed images= 161
# failed images= 331
# pending images= 8
# ------------------
# Status of batch 5:
# completed images= 164
# failed images= 331
# pending images= 5
# ------------------
# Status of batch 5:
# completed images= 167
# failed images= 332
# pending images= 1
# ------------------
# Status of batch 5:
# completed images= 167
# failed images= 333
# pending images= 0
# ------------------
# Batch 6: Retrieving images 16701 to 17200 of a total of 166117
# Status of batch 6:
# completed images= 37
# failed images= 38
# pending images= 425
# ------------------
# Status of batch 6:
# completed images= 55
# failed images= 50
# pending images= 395
# ------------------
# Status of batch 6:
# completed images= 69
# failed images= 61
# pending images= 370
# ------------------
# Status of batch 6:
# completed images= 77
# failed images= 78
# pending images= 345
# ------------------
# Status of batch 6:
# completed images= 90
# failed images= 90
# pending images= 320
# ------------------
# Status of batch 6:
# completed images= 102
# failed images= 96
# pending images= 302
# ------------------
# Status of batch 6:
# completed images= 114
# failed images= 102
# pending images= 284
# ------------------
# Status of batch 6:
# completed images= 127
# failed images= 107
# pending images= 266
# ------------------
# Status of batch 6:
# completed images= 135
# failed images= 114
# pending images= 251
# ------------------
# Status of batch 6:
# completed images= 141
# failed images= 119
# pending images= 240
# ------------------
# Status of batch 6:
# completed images= 150
# failed images= 125
# pending images= 225
# ------------------
# Status of batch 6:
# completed images= 158
# failed images= 131
# pending images= 211
# ------------------
# Status of batch 6:
# completed images= 168
# failed images= 137
# pending images= 195
# ------------------
# Status of batch 6:
# completed images= 177
# failed images= 143
# pending images= 180
# ------------------
# Status of batch 6:
# completed images= 185
# failed images= 149
# pending images= 166
# ------------------
# Status of batch 6:
# completed images= 195
# failed images= 153
# pending images= 152
# ------------------
# Status of batch 6:
# completed images= 195
# failed images= 171
# pending images= 134
# ------------------
# Status of batch 6:
# completed images= 204
# failed images= 172
# pending images= 124
# ------------------
# Status of batch 6:
# completed images= 207
# failed images= 177
# pending images= 116
# ------------------
# Status of batch 6:
# completed images= 211
# failed images= 177
# pending images= 112
# ------------------
# Status of batch 6:
# completed images= 214
# failed images= 188
# pending images= 98
# ------------------
# Status of batch 6:
# completed images= 215
# failed images= 203
# pending images= 82
# ------------------
# Status of batch 6:
# completed images= 215
# failed images= 218
# pending images= 67
# ------------------
# Status of batch 6:
# completed images= 215
# failed images= 235
# pending images= 50
# ------------------
# Status of batch 6:
# completed images= 215
# failed images= 246
# pending images= 39
# ------------------
# Status of batch 6:
# completed images= 217
# failed images= 247
# pending images= 36
# ------------------
# Status of batch 6:
# completed images= 220
# failed images= 247
# pending images= 33
# ------------------
# Status of batch 6:
# completed images= 223
# failed images= 247
# pending images= 30
# ------------------
# Status of batch 6:
# completed images= 225
# failed images= 251
# pending images= 24
# ------------------
# Status of batch 6:
# completed images= 225
# failed images= 260
# pending images= 15
# ------------------
# Status of batch 6:
# completed images= 225
# failed images= 266
# pending images= 9
# ------------------
# Status of batch 6:
# completed images= 225
# failed images= 272
# pending images= 3
# ------------------
# Status of batch 6:
# completed images= 225
# failed images= 275
# pending images= 0
# ------------------
# Batch 7: Retrieving images 17201 to 17700 of a total of 166117
# Status of batch 7:
# completed images= 37
# failed images= 50
# pending images= 413
# ------------------
# Status of batch 7:
# completed images= 53
# failed images= 56
# pending images= 391
# ------------------
# Status of batch 7:
# completed images= 68
# failed images= 68
# pending images= 364
# ------------------
# Status of batch 7:
# completed images= 82
# failed images= 73
# pending images= 345
# ------------------
# Status of batch 7:
# completed images= 96
# failed images= 80
# pending images= 324
# ------------------
# Status of batch 7:
# completed images= 107
# failed images= 86
# pending images= 307
# ------------------
# Status of batch 7:
# completed images= 118
# failed images= 98
# pending images= 284
# ------------------
# Status of batch 7:
# completed images= 131
# failed images= 104
# pending images= 265
# ------------------
# Status of batch 7:
# completed images= 139
# failed images= 110
# pending images= 251
# ------------------
# Status of batch 7:
# completed images= 149
# failed images= 116
# pending images= 235
# ------------------
# Status of batch 7:
# completed images= 155
# failed images= 116
# pending images= 229
# ------------------
# Status of batch 7:
# completed images= 166
# failed images= 122
# pending images= 212
# ------------------
# Status of batch 7:
# completed images= 171
# failed images= 128
# pending images= 201
# ------------------
# Status of batch 7:
# completed images= 178
# failed images= 134
# pending images= 188
# ------------------
# Status of batch 7:
# completed images= 188
# failed images= 138
# pending images= 174
# ------------------
# Status of batch 7:
# completed images= 192
# failed images= 140
# pending images= 168
# ------------------
# Status of batch 7:
# completed images= 197
# failed images= 147
# pending images= 156
# ------------------
# Status of batch 7:
# completed images= 201
# failed images= 162
# pending images= 137
# ------------------
# Status of batch 7:
# completed images= 208
# failed images= 168
# pending images= 124
# ------------------
# Status of batch 7:
# completed images= 214
# failed images= 168
# pending images= 118
# ------------------
# Status of batch 7:
# completed images= 218
# failed images= 174
# pending images= 108
# ------------------
# Status of batch 7:
# completed images= 225
# failed images= 174
# pending images= 101
# ------------------
# Status of batch 7:
# completed images= 228
# failed images= 180
# pending images= 92
# ------------------
# Status of batch 7:
# completed images= 234
# failed images= 180
# pending images= 86
# ------------------
# Status of batch 7:
# completed images= 239
# failed images= 186
# pending images= 75
# ------------------
# Status of batch 7:
# completed images= 245
# failed images= 186
# pending images= 69
# ------------------
# Status of batch 7:
# completed images= 248
# failed images= 192
# pending images= 60
# ------------------
# Status of batch 7:
# completed images= 253
# failed images= 192
# pending images= 55
# ------------------
# Status of batch 7:
# completed images= 256
# failed images= 194
# pending images= 50
# ------------------
# Status of batch 7:
# completed images= 258
# failed images= 204
# pending images= 38
# ------------------
# Status of batch 7:
# completed images= 258
# failed images= 210
# pending images= 32
# ------------------
# Status of batch 7:
# completed images= 259
# failed images= 214
# pending images= 27
# ------------------
# Status of batch 7:
# completed images= 262
# failed images= 214
# pending images= 24
# ------------------
# Status of batch 7:
# completed images= 265
# failed images= 214
# pending images= 21
# ------------------
# Status of batch 7:
# completed images= 268
# failed images= 216
# pending images= 16
# ------------------
# Status of batch 7:
# completed images= 268
# failed images= 220
# pending images= 12
# ------------------
# Status of batch 7:
# completed images= 271
# failed images= 220
# pending images= 9
# ------------------
# Status of batch 7:
# completed images= 273
# failed images= 220
# pending images= 7
# ------------------
# Status of batch 7:
# completed images= 275
# failed images= 220
# pending images= 5
# ------------------
# Status of batch 7:
# completed images= 277
# failed images= 221
# pending images= 2
# ------------------
# Status of batch 7:
# completed images= 278
# failed images= 222
# pending images= 0
# ------------------
# Batch 8: Retrieving images 17701 to 18200 of a total of 166117
# Status of batch 8:
# completed images= 37
# failed images= 22
# pending images= 441
# ------------------
# Status of batch 8:
# completed images= 55
# failed images= 34
# pending images= 411
# ------------------
# Status of batch 8:
# completed images= 70
# failed images= 46
# pending images= 384
# ------------------
# Status of batch 8:
# completed images= 80
# failed images= 65
# pending images= 355
# ------------------
# Status of batch 8:
# completed images= 88
# failed images= 84
# pending images= 328
# ------------------
# Status of batch 8:
# completed images= 100
# failed images= 95
# pending images= 305
# ------------------
# Status of batch 8:
# completed images= 110
# failed images= 104
# pending images= 286
# ------------------
# Status of batch 8:
# completed images= 113
# failed images= 118
# pending images= 269
# ------------------
# Status of batch 8:
# completed images= 122
# failed images= 124
# pending images= 254
# ------------------
# Status of batch 8:
# completed images= 130
# failed images= 130
# pending images= 240
# ------------------
# Status of batch 8:
# completed images= 140
# failed images= 134
# pending images= 226
# ------------------
# Status of batch 8:
# completed images= 148
# failed images= 136
# pending images= 216
# ------------------
# Status of batch 8:
# completed images= 154
# failed images= 142
# pending images= 204
# ------------------
# Status of batch 8:
# completed images= 160
# failed images= 148
# pending images= 192
# ------------------
# Status of batch 8:
# completed images= 169
# failed images= 148
# pending images= 183
# ------------------
# Status of batch 8:
# completed images= 174
# failed images= 154
# pending images= 172
# ------------------
# Status of batch 8:
# completed images= 181
# failed images= 160
# pending images= 159
# ------------------
# Status of batch 8:
# completed images= 187
# failed images= 160
# pending images= 153
# ------------------
# Status of batch 8:
# completed images= 191
# failed images= 166
# pending images= 143
# ------------------
# Status of batch 8:
# completed images= 196
# failed images= 166
# pending images= 138
# ------------------
# Status of batch 8:
# completed images= 202
# failed images= 172
# pending images= 126
# ------------------
# Status of batch 8:
# completed images= 209
# failed images= 172
# pending images= 119
# ------------------
# Status of batch 8:
# completed images= 213
# failed images= 178
# pending images= 109
# ------------------
# Status of batch 8:
# completed images= 219
# failed images= 179
# pending images= 102
# ------------------
# Status of batch 8:
# completed images= 223
# failed images= 184
# pending images= 93
# ------------------
# Status of batch 8:
# completed images= 230
# failed images= 188
# pending images= 82
# ------------------
# Status of batch 8:
# completed images= 238
# failed images= 190
# pending images= 72
# ------------------
# Status of batch 8:
# completed images= 243
# failed images= 196
# pending images= 61
# ------------------
# Status of batch 8:
# completed images= 247
# failed images= 196
# pending images= 57
# ------------------
# Status of batch 8:
# completed images= 250
# failed images= 201
# pending images= 49
# ------------------
# Status of batch 8:
# completed images= 252
# failed images= 202
# pending images= 46
# ------------------
# Status of batch 8:
# completed images= 255
# failed images= 202
# pending images= 43
# ------------------
# Status of batch 8:
# completed images= 258
# failed images= 202
# pending images= 40
# ------------------
# Status of batch 8:
# completed images= 260
# failed images= 209
# pending images= 31
# ------------------
# Status of batch 8:
# completed images= 260
# failed images= 216
# pending images= 24
# ------------------
# Status of batch 8:
# completed images= 260
# failed images= 224
# pending images= 16
# ------------------
# Status of batch 8:
# completed images= 260
# failed images= 229
# pending images= 11
# ------------------
# Status of batch 8:
# completed images= 260
# failed images= 236
# pending images= 4
# ------------------
# Status of batch 8:
# completed images= 260
# failed images= 240
# pending images= 0
# ------------------
# Batch 9: Retrieving images 18201 to 18700 of a total of 166117
# Status of batch 9:
# completed images= 20
# failed images= 75
# pending images= 405
# ------------------
# Status of batch 9:
# completed images= 36
# failed images= 82
# pending images= 382
# ------------------
# Status of batch 9:
# completed images= 50
# failed images= 94
# pending images= 356
# ------------------
# Status of batch 9:
# completed images= 63
# failed images= 100
# pending images= 337
# ------------------
# Status of batch 9:
# completed images= 77
# failed images= 106
# pending images= 317
# ------------------
# Status of batch 9:
# completed images= 89
# failed images= 113
# pending images= 298
# ------------------
# Status of batch 9:
# completed images= 100
# failed images= 124
# pending images= 276
# ------------------
# Status of batch 9:
# completed images= 109
# failed images= 129
# pending images= 262
# ------------------
# Status of batch 9:
# completed images= 119
# failed images= 130
# pending images= 251
# ------------------
# Status of batch 9:
# completed images= 127
# failed images= 135
# pending images= 238
# ------------------
# Status of batch 9:
# completed images= 136
# failed images= 141
# pending images= 223
# ------------------
# Status of batch 9:
# completed images= 146
# failed images= 147
# pending images= 207
# ------------------
# Status of batch 9:
# completed images= 150
# failed images= 167
# pending images= 183
# ------------------
# Status of batch 9:
# completed images= 156
# failed images= 169
# pending images= 175
# ------------------
# Status of batch 9:
# completed images= 163
# failed images= 175
# pending images= 162
# ------------------
# Status of batch 9:
# completed images= 170
# failed images= 179
# pending images= 151
# ------------------
# Status of batch 9:
# completed images= 176
# failed images= 181
# pending images= 143
# ------------------
# Status of batch 9:
# completed images= 180
# failed images= 187
# pending images= 133
# ------------------
# Status of batch 9:
# completed images= 189
# failed images= 188
# pending images= 123
# ------------------
# Status of batch 9:
# completed images= 192
# failed images= 192
# pending images= 116
# ------------------
# Status of batch 9:
# completed images= 198
# failed images= 193
# pending images= 109
# ------------------
# Status of batch 9:
# completed images= 203
# failed images= 199
# pending images= 98
# ------------------
# Status of batch 9:
# completed images= 209
# failed images= 202
# pending images= 89
# ------------------
# Status of batch 9:
# completed images= 213
# failed images= 205
# pending images= 82
# ------------------
# Status of batch 9:
# completed images= 219
# failed images= 206
# pending images= 75
# ------------------
# Status of batch 9:
# completed images= 220
# failed images= 211
# pending images= 69
# ------------------
# Status of batch 9:
# completed images= 224
# failed images= 211
# pending images= 65
# ------------------
# Status of batch 9:
# completed images= 229
# failed images= 213
# pending images= 58
# ------------------
# Status of batch 9:
# completed images= 231
# failed images= 217
# pending images= 52
# ------------------
# Status of batch 9:
# completed images= 236
# failed images= 217
# pending images= 47
# ------------------
# Status of batch 9:
# completed images= 240
# failed images= 219
# pending images= 41
# ------------------
# Status of batch 9:
# completed images= 240
# failed images= 228
# pending images= 32
# ------------------
# Status of batch 9:
# completed images= 240
# failed images= 236
# pending images= 24
# ------------------
# Status of batch 9:
# completed images= 240
# failed images= 238
# pending images= 22
# ------------------
# Status of batch 9:
# completed images= 242
# failed images= 239
# pending images= 19
# ------------------
# Status of batch 9:
# completed images= 245
# failed images= 239
# pending images= 16
# ------------------
# Status of batch 9:
# completed images= 248
# failed images= 239
# pending images= 13
# ------------------
# Status of batch 9:
# completed images= 250
# failed images= 243
# pending images= 7
# ------------------
# Status of batch 9:
# completed images= 251
# failed images= 244
# pending images= 5
# ------------------
# Status of batch 9:
# completed images= 252
# failed images= 245
# pending images= 3
# ------------------
# Status of batch 9:
# completed images= 252
# failed images= 245
# pending images= 3
# ------------------
# Status of batch 9:
# completed images= 255
# failed images= 245
# pending images= 0
# ------------------
# Batch 10: Retrieving images 18701 to 19200 of a total of 166117
# Status of batch 10:
# completed images= 41
# failed images= 24
# pending images= 435
# ------------------
# Status of batch 10:
# completed images= 55
# failed images= 36
# pending images= 409
# ------------------
# Status of batch 10:
# completed images= 71
# failed images= 42
# pending images= 387
# ------------------
# Status of batch 10:
# completed images= 84
# failed images= 51
# pending images= 365
# ------------------
# Status of batch 10:
# completed images= 98
# failed images= 60
# pending images= 342
# ------------------
# Status of batch 10:
# completed images= 109
# failed images= 66
# pending images= 325
# ------------------
# Status of batch 10:
# completed images= 121
# failed images= 72
# pending images= 307
# ------------------
# Status of batch 10:
# completed images= 133
# failed images= 79
# pending images= 288
# ------------------
# Status of batch 10:
# completed images= 143
# failed images= 84
# pending images= 273
# ------------------
# Status of batch 10:
# completed images= 153
# failed images= 94
# pending images= 253
# ------------------
# Status of batch 10:
# completed images= 165
# failed images= 98
# pending images= 237
# ------------------
# Status of batch 10:
# completed images= 175
# failed images= 102
# pending images= 223
# ------------------
# Status of batch 10:
# completed images= 182
# failed images= 108
# pending images= 210
# ------------------
# Status of batch 10:
# completed images= 193
# failed images= 114
# pending images= 193
# ------------------
# Status of batch 10:
# completed images= 200
# failed images= 120
# pending images= 180
# ------------------
# Status of batch 10:
# completed images= 208
# failed images= 126
# pending images= 166
# ------------------
# Status of batch 10:
# completed images= 218
# failed images= 132
# pending images= 150
# ------------------
# Status of batch 10:
# completed images= 225
# failed images= 138
# pending images= 137
# ------------------
# Status of batch 10:
# completed images= 231
# failed images= 138
# pending images= 131
# ------------------
# Status of batch 10:
# completed images= 238
# failed images= 144
# pending images= 118
# ------------------
# Status of batch 10:
# completed images= 243
# failed images= 144
# pending images= 113
# ------------------
# Status of batch 10:
# completed images= 248
# failed images= 150
# pending images= 102
# ------------------
# Status of batch 10:
# completed images= 255
# failed images= 152
# pending images= 93
# ------------------
# Status of batch 10:
# completed images= 258
# failed images= 156
# pending images= 86
# ------------------
# Status of batch 10:
# completed images= 263
# failed images= 161
# pending images= 76
# ------------------
# Status of batch 10:
# completed images= 267
# failed images= 161
# pending images= 72
# ------------------
# Status of batch 10:
# completed images= 273
# failed images= 163
# pending images= 64
# ------------------
# Status of batch 10:
# completed images= 275
# failed images= 167
# pending images= 58
# ------------------
# Status of batch 10:
# completed images= 280
# failed images= 167
# pending images= 53
# ------------------
# Status of batch 10:
# completed images= 284
# failed images= 170
# pending images= 46
# ------------------
# Status of batch 10:
# completed images= 286
# failed images= 173
# pending images= 41
# ------------------
# Status of batch 10:
# completed images= 289
# failed images= 173
# pending images= 38
# ------------------
# Status of batch 10:
# completed images= 293
# failed images= 173
# pending images= 34
# ------------------
# Status of batch 10:
# completed images= 294
# failed images= 179
# pending images= 27
# ------------------
# Status of batch 10:
# completed images= 297
# failed images= 179
# pending images= 24
# ------------------
# Status of batch 10:
# completed images= 300
# failed images= 179
# pending images= 21
# ------------------
# Status of batch 10:
# completed images= 303
# failed images= 182
# pending images= 15
# ------------------
# Status of batch 10:
# completed images= 304
# failed images= 184
# pending images= 12
# ------------------
# Status of batch 10:
# completed images= 306
# failed images= 184
# pending images= 10
# ------------------
# Status of batch 10:
# completed images= 307
# failed images= 185
# pending images= 8
# ------------------
# Status of batch 10:
# completed images= 310
# failed images= 185
# pending images= 5
# ------------------
# Status of batch 10:
# completed images= 313
# failed images= 185
# pending images= 2
# ------------------
# Status of batch 10:
# completed images= 314
# failed images= 186
# pending images= 0
# ------------------
# Batch 11: Retrieving images 19201 to 19700 of a total of 166117
# Status of batch 11:
# completed images= 50
# failed images= 66
# pending images= 384
# ------------------
# Status of batch 11:
# completed images= 66
# failed images= 73
# pending images= 361
# ------------------
# Status of batch 11:
# completed images= 75
# failed images= 111
# pending images= 314
# ------------------
# Status of batch 11:
# completed images= 90
# failed images= 118
# pending images= 292
# ------------------
# Status of batch 11:
# completed images= 100
# failed images= 129
# pending images= 271
# ------------------
# Status of batch 11:
# completed images= 111
# failed images= 135
# pending images= 254
# ------------------
# Status of batch 11:
# completed images= 121
# failed images= 141
# pending images= 238
# ------------------
# Status of batch 11:
# completed images= 130
# failed images= 145
# pending images= 225
# ------------------
# Status of batch 11:
# completed images= 140
# failed images= 152
# pending images= 208
# ------------------
# Status of batch 11:
# completed images= 149
# failed images= 153
# pending images= 198
# ------------------
# Status of batch 11:
# completed images= 156
# failed images= 159
# pending images= 185
# ------------------
# Status of batch 11:
# completed images= 164
# failed images= 165
# pending images= 171
# ------------------
# Status of batch 11:
# completed images= 173
# failed images= 171
# pending images= 156
# ------------------
# Status of batch 11:
# completed images= 179
# failed images= 173
# pending images= 148
# ------------------
# Status of batch 11:
# completed images= 184
# failed images= 176
# pending images= 140
# ------------------
# Status of batch 11:
# completed images= 189
# failed images= 178
# pending images= 133
# ------------------
# Status of batch 11:
# completed images= 193
# failed images= 182
# pending images= 125
# ------------------
# Status of batch 11:
# completed images= 200
# failed images= 188
# pending images= 112
# ------------------
# Status of batch 11:
# completed images= 208
# failed images= 189
# pending images= 103
# ------------------
# Status of batch 11:
# completed images= 210
# failed images= 206
# pending images= 84
# ------------------
# Status of batch 11:
# completed images= 210
# failed images= 220
# pending images= 70
# ------------------
# Status of batch 11:
# completed images= 212
# failed images= 226
# pending images= 62
# ------------------
# Status of batch 11:
# completed images= 216
# failed images= 226
# pending images= 58
# ------------------
# Status of batch 11:
# completed images= 220
# failed images= 227
# pending images= 53
# ------------------
# Status of batch 11:
# completed images= 220
# failed images= 231
# pending images= 49
# ------------------
# Status of batch 11:
# completed images= 224
# failed images= 231
# pending images= 45
# ------------------
# Status of batch 11:
# completed images= 228
# failed images= 232
# pending images= 40
# ------------------
# Status of batch 11:
# completed images= 230
# failed images= 234
# pending images= 36
# ------------------
# Status of batch 11:
# completed images= 230
# failed images= 237
# pending images= 33
# ------------------
# Status of batch 11:
# completed images= 230
# failed images= 240
# pending images= 30
# ------------------
# Status of batch 11:
# completed images= 230
# failed images= 250
# pending images= 20
# ------------------
# Status of batch 11:
# completed images= 231
# failed images= 254
# pending images= 15
# ------------------
# Status of batch 11:
# completed images= 233
# failed images= 254
# pending images= 13
# ------------------
# Status of batch 11:
# completed images= 235
# failed images= 254
# pending images= 11
# ------------------
# Status of batch 11:
# completed images= 237
# failed images= 254
# pending images= 9
# ------------------
# Status of batch 11:
# completed images= 240
# failed images= 259
# pending images= 1
# ------------------
# Status of batch 11:
# completed images= 240
# failed images= 260
# pending images= 0
# ------------------
# Batch 12: Retrieving images 19701 to 20200 of a total of 166117
# Status of batch 12:
# completed images= 23
# failed images= 12
# pending images= 465
# ------------------
# Status of batch 12:
# ...
# failed images= 194
# pending images= 40
# ------------------
# Status of batch 13:
# completed images= 269
# failed images= 194
# pending images= 37
# ------------------
# Status of batch 13:
# completed images= 273
# failed images= 194
# pending images= 33
# ------------------
# Status of batch 13:
# completed images= 275
# failed images= 195
# pending images= 30
# ------------------
# Status of batch 13:
# completed images= 277
# failed images= 200
# pending images= 23
# ------------------
# Status of batch 13:
# completed images= 280
# failed images= 200
# pending images= 20
# ------------------
# Status of batch 13:
# completed images= 283
# failed images= 200
# pending images= 17
# ------------------
# Status of batch 13:
# completed images= 285
# failed images= 200
# pending images= 15
# ------------------
# Status of batch 13:
# completed images= 286
# failed images= 204
# pending images= 10
# ------------------
# Status of batch 13:
# completed images= 287
# failed images= 206
# pending images= 7
# ------------------
# Status of batch 13:
# completed images= 289
# failed images= 206
# pending images= 5
# ------------------
# Status of batch 13:
# completed images= 291
# failed images= 206
# pending images= 3
# ------------------
# Status of batch 13:
# completed images= 293
# failed images= 206
# pending images= 1
# ------------------
# Status of batch 13:
# completed images= 294
# failed images= 206
# pending images= 0
# ------------------
# Batch 14: Retrieving images 20701 to 21200 of a total of 166117
# Status of batch 14:
# completed images= 32
# failed images= 39
# pending images= 429
# ------------------
# Status of batch 14:
# completed images= 41
# failed images= 44
# pending images= 415
# ------------------
# Status of batch 14:
# completed images= 55
# failed images= 52
# pending images= 393
# ------------------
# Status of batch 14:
# completed images= 67
# failed images= 58
# pending images= 375
# ------------------
# Status of batch 14:
# completed images= 82
# failed images= 67
# pending images= 351
# ------------------
# Status of batch 14:
# completed images= 92
# failed images= 72
# pending images= 336
# ------------------
# Status of batch 14:
# completed images= 102
# failed images= 81
# pending images= 317
# ------------------
# Status of batch 14:
# completed images= 112
# failed images= 88
# pending images= 300
# ------------------
# Status of batch 14:
# completed images= 120
# failed images= 88
# pending images= 292
# ------------------
# Status of batch 14:
# completed images= 122
# failed images= 110
# pending images= 268
# ------------------
# Status of batch 14:
# completed images= 132
# failed images= 114
# pending images= 254
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 116
# pending images= 243
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 138
# pending images= 221
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 167
# pending images= 192
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 188
# pending images= 171
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 203
# pending images= 156
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 217
# pending images= 142
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 237
# pending images= 122
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 250
# pending images= 109
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 269
# pending images= 90
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 281
# pending images= 78
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 293
# pending images= 66
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 298
# pending images= 61
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 312
# pending images= 47
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 321
# pending images= 38
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 330
# pending images= 29
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 341
# pending images= 18
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 345
# pending images= 14
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 351
# pending images= 8
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 357
# pending images= 2
# ------------------
# Status of batch 14:
# completed images= 141
# failed images= 359
# pending images= 0
# ------------------
# Batch 15: Retrieving images 21201 to 21700 of a total of 166117
# Status of batch 15:
# completed images= 0
# failed images= 101
# pending images= 399
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 144
# pending images= 356
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 180
# pending images= 320
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 212
# pending images= 288
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 240
# pending images= 260
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 261
# pending images= 239
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 290
# pending images= 210
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 317
# pending images= 183
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 336
# pending images= 164
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 349
# pending images= 151
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 363
# pending images= 137
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 377
# pending images= 123
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 389
# pending images= 111
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 403
# pending images= 97
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 411
# pending images= 89
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 424
# pending images= 76
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 434
# pending images= 66
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 444
# pending images= 56
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 449
# pending images= 51
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 455
# pending images= 45
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 460
# pending images= 40
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 468
# pending images= 32
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 471
# pending images= 29
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 473
# pending images= 27
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 475
# pending images= 25
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 482
# pending images= 18
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 485
# pending images= 15
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 494
# pending images= 6
# ------------------
# Status of batch 15:
# completed images= 0
# failed images= 500
# pending images= 0
# ------------------
# Batch 16: Retrieving images 21701 to 22200 of a total of 166117
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 143
#     140 for i in range(lower_i,upper_i):
#     141     #checking status of each task
#     142     if df.loc[i,'task_status']=='_' or df.loc[i,'task_status']=='READY' or df.loc[i,'task_status']=='RUNNING':
# --> 143         df.loc[i,'task_status']=tasks[i-starting_index].status()['state'] #use when restarting list of tasks
#     144         #dataset.loc[i,'task_status']=tasks[i].status()['state']
#     145
#     146 #updating batch status
#     147 batch_status=df.loc[lower_i:upper_i-1,'task_status'].value_counts()
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/batch.py:176, in Task.status(self)
#     163 """Fetches the current status of the task.
#     164
#     165 Returns:
#    (...)
#     173   May also include other fields.
#     174 """
#     175 if self.operation_name:
# --> 176   operation = data.getOperation(self.operation_name)
#     177   result = _cloud_api_utils.convert_operation_to_task(operation)
#     178   if result['state'] == 'UNKNOWN':
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/data.py:1701, in getOperation(operation_name)
#    1691 def getOperation(operation_name: str) -> Any:
#    1692   """Retrieves the status of a long-running operation.
#    1693
#    1694   Args:
#    (...)
#    1699     An Operation status dictionary for the requested operation.
#    1700   """
# -> 1701   return _execute_cloud_call(
#    1702       _get_cloud_projects().operations().get(name=operation_name)
#    1703   )
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/data.py:402, in _execute_cloud_call(call, num_retries)
#     388 """Executes a Cloud API call and translates errors to EEExceptions.
#     389
#     390 Args:
#    (...)
#     399   EEException if the call fails.
#     400 """
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#     404   raise _translate_cloud_exception(e)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/ee/_cloud_api_utils.py:70, in _Http.request(***failed resolving arguments***)
#      63 del redirections  # Ignored
#      65 try:
#      66   # googleapiclient is expecting an httplib2 object, and doesn't include
#      67   # requests error in the list of transient errors. Therefore, transient
#      68   # requests errors should be converted to kinds that googleapiclient
#      69   # consider transient.
# ---> 70   response = self._session.request(
#      71       method, uri, data=body, headers=headers, timeout=self._timeout
#      72   )
#      73 except requests.exceptions.ConnectionError as connection_error:
#      74   raise ConnectionError(connection_error) from connection_error
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/urllib3/response.py:1040, in HTTPResponse.stream(self, amt, decode_content)
#    1024 """
#    1025 A generator wrapper for the read() method. A call will block until
#    1026 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1037     'content-encoding' header.
#    1038 """
#    1039 if self.chunked and self.supports_chunked_reads():
# -> 1040     yield from self.read_chunked(amt, decode_content=decode_content)
#    1041 else:
#    1042     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/urllib3/response.py:1184, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1181     return None
#    1183 while True:
# -> 1184     self._update_chunk_length()
#    1185     if self.chunk_left == 0:
#    1186         break
#
# File ~/miniconda3/envs/ee/lib/python3.12/site-packages/urllib3/response.py:1108, in HTTPResponse._update_chunk_length(self)
#    1106 if self.chunk_left is not None:
#    1107     return None
# -> 1108 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1109 line = line.split(b";", 1)[0]
#    1110 try:
#
# File ~/miniconda3/envs/ee/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/miniconda3/envs/ee/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/ee/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from keras.models import Model
from keras.layers import TimeDistributed, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Dropout, Bidirectional, Input, concatenate,Reshape
from keras.utils import plot_model

# Definición del modelo CNN
input1 = Input(shape=(None, 100, 100, 8)) # Asume que tus imágenes son de 100x100 con 8 canales
cnn = TimeDistributed(Conv2D(64, kernel_size=3, activation='relu'))(input1)
cnn = TimeDistributed(MaxPooling2D(2))(cnn)
cnn = TimeDistributed(Conv2D(128, kernel_size=3, activation='relu'))(cnn)
cnn = TimeDistributed(MaxPooling2D(2))(cnn)
cnn = TimeDistributed(Conv2D(64, kernel_size=3, activation='relu'))(cnn)
cnn = TimeDistributed(MaxPooling2D(2))(cnn)
cnn = TimeDistributed(Flatten())(cnn)

# Definición del modelo LSTM
input2 = Input(shape=(None, 14)) # Asume que tienes 14 características tabuladas
dense = TimeDistributed(Dense(128, activation='relu'))(input2)
dense = TimeDistributed(Dropout(0.5))(dense)
dense = TimeDistributed(Dense(64, activation='relu'))(dense)
dense = TimeDistributed(Dropout(0.5))(dense)
dense = TimeDistributed(Dense(32, activation='relu'))(dense)

# Combinación de los modelos
merge = concatenate([cnn, dense])
lstm = Bidirectional(LSTM(100, return_sequences=True))(merge)
lstm = Dropout(0.5)(lstm)
lstm = Bidirectional(LSTM(100, return_sequences=False))(lstm)
lstm = Dropout(0.5)(lstm)

# Capa de salida
output = Dense(1, activation='linear')(lstm) # Asume que estás haciendo una regresión

# Creación del modelo
model = Model([input1, input2], output)
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
